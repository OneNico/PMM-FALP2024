# %%
import os
import pydicom
import numpy as np
import pandas as pd
import cv2
from pydicom.pixel_data_handlers.util import apply_voi_lut

# ---------------------- Configuración de Rutas ---------------------- #

# Rutas a las carpetas y archivos CSV
csv_path = '/Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/csv/filtered_with_image_names.csv'
source_images_dir = '/Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc'
output_root = '/Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG'

# Ruta para guardar el nuevo CSV
csv_output_path = '/Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/csv/png_masasycalcificaciones.csv'

# ---------------------- Crear Estructura de Directorios ---------------------- #

def create_output_directories(output_root):
    categories = ['masas', 'calcificaciones']
    birads_subcategories = {
        'benigno': ['BI-RADS 3'],
        'sospechoso': ['BI-RADS 4'],
        'maligno': ['BI-RADS 5']
    }

    for category in categories:
        for subcategory, birads_list in birads_subcategories.items():
            for birads in birads_list:
                path = os.path.join(output_root, category, subcategory)
                os.makedirs(path, exist_ok=True)
                print(f"Creada o verificada la carpeta: {path}")

create_output_directories(output_root)

# ---------------------- Funciones de Procesamiento ---------------------- #

# Función para mapear BIRADS a subcategorías
def map_birads_to_subcategory(birads):
    if birads == 'BI-RADS 3':
        return 'benigno'
    elif birads == 'BI-RADS 4':
        return 'sospechoso'
    elif birads == 'BI-RADS 5':
        return 'maligno'
    else:
        print(f"Advertencia: BIRADS desconocido '{birads}'. Asignando a 'benigno'.")
        return 'benigno'

# Función para procesar y convertir DICOM a PNG
def dicom_to_png(dicom_path, image_name):
    try:
        dicom = pydicom.dcmread(dicom_path)
        original_image = dicom.pixel_array

        # Aplicar VOI LUT con prefer_lut=True (priorizando LUT si está presente)
        img_windowed = apply_voi_lut(original_image, dicom, prefer_lut=True)

        # Manejar Photometric Interpretation si es MONOCHROME1 (invertir la imagen)
        photometric_interpretation = dicom.get('PhotometricInterpretation', 'UNKNOWN')
        if photometric_interpretation == 'MONOCHROME1':
            img_windowed = img_windowed.max() - img_windowed
            print(f"Imagen '{image_name}' invertida debido a Photometric Interpretation: {photometric_interpretation}")
        else:
            print(f"Imagen '{image_name}' Photometric Interpretation: {photometric_interpretation}")

        # Normalizar la imagen para que esté en el rango [0, 255]
        img_normalized = (img_windowed - img_windowed.min()) / (img_windowed.max() - img_windowed.min()) * 255
        img_normalized = img_normalized.astype(np.uint8)

        # Redimensionar la imagen a 224x224 píxeles
        img_resized = cv2.resize(img_normalized, (224, 224), interpolation=cv2.INTER_AREA)

        return img_resized

    except Exception as e:
        print(f"Error al procesar {dicom_path}: {e}")
        return None

# Función para obtener la ruta del archivo DICOM usando image_id
def get_dicom_path(image_id, source_dir):
    # Posibles extensiones de archivo
    extensions = ['.dicom', '.dcm']
    for ext in extensions:
        dicom_filename = f"{image_id}{ext}"
        dicom_path = os.path.join(source_dir, dicom_filename)
        if os.path.exists(dicom_path):
            print(f"Encontrado DICOM para '{image_id}': {dicom_path}")
            return dicom_path
    # Si no se encuentra en la raíz, buscar en subdirectorios
    for root, dirs, files in os.walk(source_dir):
        for ext in extensions:
            dicom_filename = f"{image_id}{ext}"
            if dicom_filename in files:
                found_path = os.path.join(root, dicom_filename)
                print(f"Encontrado DICOM para '{image_id}' en subdirectorio: {found_path}")
                return found_path
    print(f"No se encontró el archivo DICOM para image_id: {image_id}")
    return None

# ---------------------- Procesamiento Principal ---------------------- #

def process_dicom_images(csv_path, source_dir, output_root, csv_output_path):
    # Leer el archivo CSV
    try:
        df = pd.read_csv(csv_path)
        print(f"CSV cargado correctamente con {len(df)} filas.")
    except Exception as e:
        print(f"Error al leer el CSV: {e}")
        return

    # Verificar columnas necesarias
    required_columns = ['image_id', 'image_name', 'finding_categories', 'finding_birads']
    for col in required_columns:
        if col not in df.columns:
            print(f"Error: La columna '{col}' no está presente en el CSV.")
            return

    # Limpiar los valores de 'finding_categories'
    df['finding_categories'] = df['finding_categories'].apply(lambda x: x.strip("[]'") if isinstance(x, str) else x)

    # Limpiar los valores de 'finding_birads' eliminando espacios adicionales
    df['finding_birads'] = df['finding_birads'].apply(lambda x: x.strip() if isinstance(x, str) else x)

    # Mostrar los valores únicos después de limpiar
    print("\nValores únicos en 'finding_categories' después de limpiar:")
    unique_categories = df['finding_categories'].unique()
    for category in unique_categories:
        print(f"- {category}")

    # Filtrar solo las categorías que contienen 'Mass' o 'Suspicious Calcification'
    # Considerando que 'finding_categories' puede tener múltiples categorías separadas por comas
    df_filtered = df[df['finding_categories'].str.contains(r'\bMass\b|\bSuspicious Calcification\b', case=False, na=False)]
    filtered_count = len(df_filtered)
    print(f"\nFiltrado de categorías 'Mass' y 'Suspicious Calcification': {filtered_count} de {len(df)} imágenes.")

    if filtered_count == 0:
        print("No hay imágenes para procesar después del filtrado.")
        return

    # NOTA: Ya no eliminamos duplicados basados en 'image_id'

    # Inicializar un diccionario para contar imágenes por categoría y subcategoría
    counts_dict = {
        'masas': {'benigno': 0, 'sospechoso': 0, 'maligno': 0},
        'calcificaciones': {'benigno': 0, 'sospechoso': 0, 'maligno': 0}
    }

    # Lista para almacenar las filas del nuevo CSV
    new_csv_data = []

    # Contador de imágenes procesadas y errores
    processed_images = 0
    failed_images = 0

    # Implementar una caché para almacenar dicom_path ya encontrados
    dicom_cache = {}

    # Recorrer cada fila del DataFrame filtrado
    for index, row in df_filtered.iterrows():
        image_id = row['image_id']
        image_name = row['image_name']
        finding_category = row['finding_categories']
        finding_birads = row['finding_birads']

        print(f"\nProcesando image_name: {image_name}, Categoría: {finding_category}, BIRADS: {finding_birads}")

        # Obtener la ruta del archivo DICOM usando image_id
        if image_id in dicom_cache:
            dicom_path = dicom_cache[image_id]
            if dicom_path is None:
                print(f"No se encontró previamente el DICOM para image_id: {image_id}. Saltando.")
                failed_images += 1
                continue
        else:
            dicom_path = get_dicom_path(image_id, source_dir)
            dicom_cache[image_id] = dicom_path

        if dicom_path is None:
            failed_images += 1
            continue  # Saltar si no se encontró el DICOM

        # Procesar la imagen DICOM y obtener la imagen normalizada y redimensionada
        img_png = dicom_to_png(dicom_path, image_name)
        if img_png is None:
            failed_images += 1
            continue  # Saltar si hubo un error en el procesamiento

        # Determinar la categoría y subcategoría
        if 'Mass' in finding_category or 'mass' in finding_category:
            category = 'masas'
        elif 'Suspicious Calcification' in finding_category or 'suspicious calcification' in finding_category:
            category = 'calcificaciones'
        else:
            print(f"Categoría desconocida '{finding_category}' para image_name {image_name}. Saltando.")
            failed_images += 1
            continue

        subcategory = map_birads_to_subcategory(finding_birads)

        # Incrementar el conteo correspondiente
        if category in counts_dict and subcategory in counts_dict[category]:
            counts_dict[category][subcategory] += 1
        else:
            # Si por alguna razón la categoría o subcategoría no existe en el diccionario
            print(f"Categoría o subcategoría no reconocida para image_name {image_name}.")
            failed_images += 1
            continue

        # Definir la ruta de guardado
        output_dir = os.path.join(output_root, category, subcategory)
        output_filename = f"{image_name}.png"
        output_path = os.path.join(output_dir, output_filename)

        # Guardar la imagen como PNG
        try:
            cv2.imwrite(output_path, img_png)
            print(f"Imagen PNG guardada en: {output_path}")
            processed_images += 1
        except Exception as e:
            print(f"Error al guardar PNG para {image_name}: {e}")
            failed_images += 1
            continue

        # Agregar la información al nuevo CSV
        new_csv_data.append({
            'image_name': image_name,
            'finding_birads': finding_birads,
            'finding_categories': finding_category
        })

    # Crear un DataFrame para el nuevo CSV
    new_csv_df = pd.DataFrame(new_csv_data)

    # Guardar el nuevo CSV
    try:
        new_csv_df.to_csv(csv_output_path, index=False)
        print(f"\nNuevo CSV guardado en: {csv_output_path}")
    except Exception as e:
        print(f"Error al guardar el nuevo CSV: {e}")

    # Mostrar los conteos
    print("\nCantidad de imágenes por categoría y subcategoría:")
    for category, subcats in counts_dict.items():
        for subcat, count in subcats.items():
            print(f"- {category.capitalize()} / {subcat.capitalize()}: {count}")
    total_processed = processed_images
    print(f"\nTotal de imágenes procesadas: {total_processed}")
    print(f"Total de imágenes fallidas: {failed_images}")

# ---------------------- Función de Procesamiento Manual ---------------------- #

def manual_process_single_image(image_id, image_name, source_dir, output_root):
    dicom_path = get_dicom_path(image_id, source_dir)
    if dicom_path:
        img_png = dicom_to_png(dicom_path, image_name)
        if img_png is not None:
            # Definir la categoría y subcategoría según tus datos
            finding_category = 'Mass'  # o 'Suspicious Calcification'
            finding_birads = 'BI-RADS 3'  # o 'BI-RADS 4', 'BI-RADS 5'

            if 'Mass' in finding_category or 'mass' in finding_category:
                category = 'masas'
            elif 'Suspicious Calcification' in finding_category or 'suspicious calcification' in finding_category:
                category = 'calcificaciones'
            else:
                print(f"Categoría desconocida '{finding_category}' para image_name {image_name}.")
                return

            subcategory = map_birads_to_subcategory(finding_birads)
            output_dir = os.path.join(output_root, category, subcategory)
            output_filename = f"{image_name}.png"
            output_path = os.path.join(output_dir, output_filename)

            # Guardar la imagen como PNG
            try:
                cv2.imwrite(output_path, img_png)
                print(f"Imagen PNG guardada manualmente en: {output_path}")
            except Exception as e:
                print(f"Error al guardar PNG para {image_name}: {e}")
        else:
            print(f"No se pudo procesar la imagen DICOM para {image_name}.")
    else:
        print(f"No se encontró el archivo DICOM para image_id: {image_id}.")

# ---------------------- Ejecutar el Procesamiento ---------------------- #

if __name__ == "__main__":
    # Ejecutar el procesamiento principal
    process_dicom_images(csv_path, source_images_dir, output_root, csv_output_path)

    # Opcional: Ejecutar el procesamiento manual de una sola imagen para verificar
    # Descomenta las siguientes líneas y reemplaza 'ejemplo_image_id' y 'ejemplo_image_name' con valores válidos
    # manual_process_single_image('ffb94da823c87898c7ce19b197dc24c9', 'ffb94da823c87898c7ce19b197dc24c9_0', source_images_dir, output_root)
# Out:
# Creada o verificada la carpeta: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno
# Creada o verificada la carpeta: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso
# Creada o verificada la carpeta: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/maligno
# Creada o verificada la carpeta: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/benigno
# Creada o verificada la carpeta: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso
# Creada o verificada la carpeta: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/maligno
# CSV cargado correctamente con 1525 filas.
#
# Valores únicos en 'finding_categories' después de limpiar:
# - Mass
# - Suspicious Calcification
#
# Filtrado de categorías 'Mass' y 'Suspicious Calcification': 1525 de 1525 imágenes.
#
# Procesando image_name: 001ade2a3cb53fd808bd2856a0df5413_0, Categoría: Mass, BIRADS: BI-RADS 4
# Encontrado DICOM para '001ade2a3cb53fd808bd2856a0df5413' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/8b202f831f93639ebcb9cccccec03b09/001ade2a3cb53fd808bd2856a0df5413.dicom
# Imagen '001ade2a3cb53fd808bd2856a0df5413_0' invertida debido a Photometric Interpretation: MONOCHROME1
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/001ade2a3cb53fd808bd2856a0df5413_0.png
#
# Procesando image_name: 001ade2a3cb53fd808bd2856a0df5413_1, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Imagen '001ade2a3cb53fd808bd2856a0df5413_1' invertida debido a Photometric Interpretation: MONOCHROME1
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/001ade2a3cb53fd808bd2856a0df5413_1.png
#
# Procesando image_name: 001ade2a3cb53fd808bd2856a0df5413_2, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Imagen '001ade2a3cb53fd808bd2856a0df5413_2' invertida debido a Photometric Interpretation: MONOCHROME1
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/001ade2a3cb53fd808bd2856a0df5413_2.png
#
# Procesando image_name: 002074412a8fc178c271fb93b55c3e29_0, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Encontrado DICOM para '002074412a8fc178c271fb93b55c3e29' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/b9c15e629cf02f501acbc194420d749c/002074412a8fc178c271fb93b55c3e29.dicom
# Imagen '002074412a8fc178c271fb93b55c3e29_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/002074412a8fc178c271fb93b55c3e29_0.png
#
# Procesando image_name: 002460132586dc0c7b88a59dce6e77bd_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para '002460132586dc0c7b88a59dce6e77bd' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/76c60021bdad852f982497bb6dfa6cf2/002460132586dc0c7b88a59dce6e77bd.dicom
# Imagen '002460132586dc0c7b88a59dce6e77bd_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/002460132586dc0c7b88a59dce6e77bd_0.png
#
# Procesando image_name: 00857417d07096982013956033da1f75_0, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Encontrado DICOM para '00857417d07096982013956033da1f75' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/14a63118d94643a3d65b32039a20b351/00857417d07096982013956033da1f75.dicom
# Imagen '00857417d07096982013956033da1f75_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/00857417d07096982013956033da1f75_0.png
#
# Procesando image_name: 008c66563c73b2f5b8e42915b2cd6af5_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para '008c66563c73b2f5b8e42915b2cd6af5' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/d101ecbe883dcfadae08720d3742ee34/008c66563c73b2f5b8e42915b2cd6af5.dicom
# Imagen '008c66563c73b2f5b8e42915b2cd6af5_0' invertida debido a Photometric Interpretation: MONOCHROME1
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/008c66563c73b2f5b8e42915b2cd6af5_0.png
#
# Procesando image_name: 00be38a5c0566291168fe381ba0028e6_0, Categoría: Mass, BIRADS: BI-RADS 4
# Encontrado DICOM para '00be38a5c0566291168fe381ba0028e6' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/38f0774c2e72c4d5407df23a43aa1ff7/00be38a5c0566291168fe381ba0028e6.dicom
# Imagen '00be38a5c0566291168fe381ba0028e6_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/00be38a5c0566291168fe381ba0028e6_0.png
#
# Procesando image_name: 00ec2be128f964da6f0b0ba179c4d138_0, Categoría: Mass, BIRADS: BI-RADS 4
# Encontrado DICOM para '00ec2be128f964da6f0b0ba179c4d138' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/c03090de258a9344e1c187f6a01bf275/00ec2be128f964da6f0b0ba179c4d138.dicom
# Imagen '00ec2be128f964da6f0b0ba179c4d138_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/00ec2be128f964da6f0b0ba179c4d138_0.png
#
# Procesando image_name: 013e4b7bcdaf536c4e37b4125ab8148b_0, Categoría: Mass, BIRADS: BI-RADS 5
# Encontrado DICOM para '013e4b7bcdaf536c4e37b4125ab8148b' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/a0f14ae866385e07fa214169675a8d03/013e4b7bcdaf536c4e37b4125ab8148b.dicom
# Imagen '013e4b7bcdaf536c4e37b4125ab8148b_0' invertida debido a Photometric Interpretation: MONOCHROME1
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/maligno/013e4b7bcdaf536c4e37b4125ab8148b_0.png
#
# Procesando image_name: 0171ab32059f4c226164a13c311f6824_0, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Encontrado DICOM para '0171ab32059f4c226164a13c311f6824' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/cfd8cbfe20b2eb3f1636454982ff6186/0171ab32059f4c226164a13c311f6824.dicom
# Imagen '0171ab32059f4c226164a13c311f6824_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/0171ab32059f4c226164a13c311f6824_0.png
#
# Procesando image_name: 01958718afdf303581e758cdf34eaf8a_0, Categoría: Mass, BIRADS: BI-RADS 4
# Encontrado DICOM para '01958718afdf303581e758cdf34eaf8a' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/27d4dc70d6f73554e4ead70f01867167/01958718afdf303581e758cdf34eaf8a.dicom
# Imagen '01958718afdf303581e758cdf34eaf8a_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/01958718afdf303581e758cdf34eaf8a_0.png
#
# Procesando image_name: 01df962b078e38500bf9dd9969a50083_0, Categoría: Mass, BIRADS: BI-RADS 5
# Encontrado DICOM para '01df962b078e38500bf9dd9969a50083' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/d746c5e878799ec8f42e2e8f6ab9a992/01df962b078e38500bf9dd9969a50083.dicom
# Imagen '01df962b078e38500bf9dd9969a50083_0' invertida debido a Photometric Interpretation: MONOCHROME1
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/maligno/01df962b078e38500bf9dd9969a50083_0.png
#
# Procesando image_name: 01fb871dc222684a9950609b62b76772_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para '01fb871dc222684a9950609b62b76772' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/e5e997bf2edc162b99863a9fdd0c7e51/01fb871dc222684a9950609b62b76772.dicom
# Imagen '01fb871dc222684a9950609b62b76772_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/01fb871dc222684a9950609b62b76772_0.png
#
# Procesando image_name: 02895cbbcb504f54c6882c4c5695f563_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para '02895cbbcb504f54c6882c4c5695f563' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/6a5fb5091c54d26f78f2439269bdaa82/02895cbbcb504f54c6882c4c5695f563.dicom
# Imagen '02895cbbcb504f54c6882c4c5695f563_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/02895cbbcb504f54c6882c4c5695f563_0.png
#
# Procesando image_name: 02b3206d267eb7f354113b0c5365127b_0, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Encontrado DICOM para '02b3206d267eb7f354113b0c5365127b' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/f0677aad26731481bcc723bd3222c035/02b3206d267eb7f354113b0c5365127b.dicom
# Imagen '02b3206d267eb7f354113b0c5365127b_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/02b3206d267eb7f354113b0c5365127b_0.png
#
# Procesando image_name: 02d253f51556e2e0af63525de2e9ff74_0, Categoría: Mass, BIRADS: BI-RADS 4
# Encontrado DICOM para '02d253f51556e2e0af63525de2e9ff74' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/545806c1949f3eb9686959d85a1a26a3/02d253f51556e2e0af63525de2e9ff74.dicom
# Imagen '02d253f51556e2e0af63525de2e9ff74_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/02d253f51556e2e0af63525de2e9ff74_0.png
#
# Procesando image_name: 02d253f51556e2e0af63525de2e9ff74_1, Categoría: Mass, BIRADS: BI-RADS 4
# Imagen '02d253f51556e2e0af63525de2e9ff74_1' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/02d253f51556e2e0af63525de2e9ff74_1.png
#
# Procesando image_name: 02d253f51556e2e0af63525de2e9ff74_2, Categoría: Mass, BIRADS: BI-RADS 4
# Imagen '02d253f51556e2e0af63525de2e9ff74_2' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/02d253f51556e2e0af63525de2e9ff74_2.png
#
# Procesando image_name: 031592807c30b54e2fb4bd2400e634e8_0, Categoría: Mass, BIRADS: BI-RADS 4
# Encontrado DICOM para '031592807c30b54e2fb4bd2400e634e8' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/175f10693af82fdf9bdf9e711697ec13/031592807c30b54e2fb4bd2400e634e8.dicom
# Imagen '031592807c30b54e2fb4bd2400e634e8_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/031592807c30b54e2fb4bd2400e634e8_0.png
#
# Procesando image_name: 032ab9e0ecd5fd673517ffa3eb805d15_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para '032ab9e0ecd5fd673517ffa3eb805d15' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/030561532b801ef4b623657ebee557bd/032ab9e0ecd5fd673517ffa3eb805d15.dicom
# Imagen '032ab9e0ecd5fd673517ffa3eb805d15_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/032ab9e0ecd5fd673517ffa3eb805d15_0.png
#
# Procesando image_name: 03674edf018ba8eef3c2857d1aa3305b_0, Categoría: Mass, BIRADS: BI-RADS 4
# Encontrado DICOM para '03674edf018ba8eef3c2857d1aa3305b' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/28605b2b2337d1a4aae65900df2a36ae/03674edf018ba8eef3c2857d1aa3305b.dicom
# Imagen '03674edf018ba8eef3c2857d1aa3305b_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/03674edf018ba8eef3c2857d1aa3305b_0.png
#
# Procesando image_name: 03b3656c726cbe0d79c86a25d4296559_0, Categoría: Mass, BIRADS: BI-RADS 5
# Encontrado DICOM para '03b3656c726cbe0d79c86a25d4296559' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/01c3c13f0b852aed00b5147c21d0e649/03b3656c726cbe0d79c86a25d4296559.dicom
# Imagen '03b3656c726cbe0d79c86a25d4296559_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/maligno/03b3656c726cbe0d79c86a25d4296559_0.png
#
# Procesando image_name: 03b3656c726cbe0d79c86a25d4296559_1, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Imagen '03b3656c726cbe0d79c86a25d4296559_1' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/03b3656c726cbe0d79c86a25d4296559_1.png
#
# Procesando image_name: 03e464754732750f5828aeb94af68b22_0, Categoría: Mass, BIRADS: BI-RADS 4
# Encontrado DICOM para '03e464754732750f5828aeb94af68b22' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/63303252b1fb34780163ab8a47ba89f9/03e464754732750f5828aeb94af68b22.dicom
# Imagen '03e464754732750f5828aeb94af68b22_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/03e464754732750f5828aeb94af68b22_0.png
#
# Procesando image_name: 040cc172596bded4092c44094dc33fb7_0, Categoría: Mass, BIRADS: BI-RADS 4
# Encontrado DICOM para '040cc172596bded4092c44094dc33fb7' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/57674c2def92287668ed5bc51092fbef/040cc172596bded4092c44094dc33fb7.dicom
# Imagen '040cc172596bded4092c44094dc33fb7_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/040cc172596bded4092c44094dc33fb7_0.png
#
# Procesando image_name: 0426e31fea8079ce30b796c80321a17c_0, Categoría: Mass, BIRADS: BI-RADS 4
# Encontrado DICOM para '0426e31fea8079ce30b796c80321a17c' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/6b1818c48d12b25aa72fcf1d22aed05a/0426e31fea8079ce30b796c80321a17c.dicom
# Imagen '0426e31fea8079ce30b796c80321a17c_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/0426e31fea8079ce30b796c80321a17c_0.png
#
# Procesando image_name: 042733688eecb852ea06140448a8b1bf_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para '042733688eecb852ea06140448a8b1bf' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/8a83a1b911d3238c144aa0e654be5dfb/042733688eecb852ea06140448a8b1bf.dicom
# Imagen '042733688eecb852ea06140448a8b1bf_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/042733688eecb852ea06140448a8b1bf_0.png
#
# Procesando image_name: 04c64dd7683662188094816c7c2ca88d_0, Categoría: Mass, BIRADS: BI-RADS 4
# Encontrado DICOM para '04c64dd7683662188094816c7c2ca88d' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/64777bbe7e1f7ee9bc9387615e62acd9/04c64dd7683662188094816c7c2ca88d.dicom
# Imagen '04c64dd7683662188094816c7c2ca88d_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/04c64dd7683662188094816c7c2ca88d_0.png
#
# Procesando image_name: 050c2f6caf47f439d62e1fc8942396f6_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para '050c2f6caf47f439d62e1fc8942396f6' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/ba35b6786b649e447fd4b0c39350b8da/050c2f6caf47f439d62e1fc8942396f6.dicom
# Imagen '050c2f6caf47f439d62e1fc8942396f6_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/050c2f6caf47f439d62e1fc8942396f6_0.png
#
# Procesando image_name: 051525b959eefb14e973acc7ab8fcfe0_0, Categoría: Mass, BIRADS: BI-RADS 4
# Encontrado DICOM para '051525b959eefb14e973acc7ab8fcfe0' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/9ca0112757065957cb751b4b8a0be110/051525b959eefb14e973acc7ab8fcfe0.dicom
# Imagen '051525b959eefb14e973acc7ab8fcfe0_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/051525b959eefb14e973acc7ab8fcfe0_0.png
#
# Procesando image_name: 0602173c47d1b21fe548b2d852433a03_0, Categoría: Mass, BIRADS: BI-RADS 4
# Encontrado DICOM para '0602173c47d1b21fe548b2d852433a03' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/08db0293a555cc089d14e6357381d42d/0602173c47d1b21fe548b2d852433a03.dicom
# Imagen '0602173c47d1b21fe548b2d852433a03_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/0602173c47d1b21fe548b2d852433a03_0.png
#
# Procesando image_name: 0602173c47d1b21fe548b2d852433a03_1, Categoría: Mass, BIRADS: BI-RADS 4
# Imagen '0602173c47d1b21fe548b2d852433a03_1' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/0602173c47d1b21fe548b2d852433a03_1.png
#
# Procesando image_name: 06073969e7453f71ac8108c6081dc9b8_0, Categoría: Mass, BIRADS: BI-RADS 4
# Encontrado DICOM para '06073969e7453f71ac8108c6081dc9b8' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/4d7251459f544291749639dd9265b804/06073969e7453f71ac8108c6081dc9b8.dicom
# Imagen '06073969e7453f71ac8108c6081dc9b8_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/06073969e7453f71ac8108c6081dc9b8_0.png
#
# Procesando image_name: 061bc49a16cad3bc2b479993f7e689f8_0, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Encontrado DICOM para '061bc49a16cad3bc2b479993f7e689f8' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/4bbb976f1f09cb84f28fa0601a902781/061bc49a16cad3bc2b479993f7e689f8.dicom
# Imagen '061bc49a16cad3bc2b479993f7e689f8_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/061bc49a16cad3bc2b479993f7e689f8_0.png
#
# Procesando image_name: 061bf98fabad5f9d99fb1919346a3a76_0, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Encontrado DICOM para '061bf98fabad5f9d99fb1919346a3a76' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/3ede3de12fc4c4bb837f7422a3a16380/061bf98fabad5f9d99fb1919346a3a76.dicom
# Imagen '061bf98fabad5f9d99fb1919346a3a76_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/061bf98fabad5f9d99fb1919346a3a76_0.png
#
# Procesando image_name: 061bf98fabad5f9d99fb1919346a3a76_1, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Imagen '061bf98fabad5f9d99fb1919346a3a76_1' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/061bf98fabad5f9d99fb1919346a3a76_1.png
#
# Procesando image_name: 061c11537a514e894a296a7d72064a90_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para '061c11537a514e894a296a7d72064a90' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/d0c9ed546f54159e70a051805c9f7499/061c11537a514e894a296a7d72064a90.dicom
# Imagen '061c11537a514e894a296a7d72064a90_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/061c11537a514e894a296a7d72064a90_0.png
#
# Procesando image_name: 064f024583e9c1a7f0152f50aac1d16d_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para '064f024583e9c1a7f0152f50aac1d16d' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/c79e16f69c355bad0291d281d674f53b/064f024583e9c1a7f0152f50aac1d16d.dicom
# Imagen '064f024583e9c1a7f0152f50aac1d16d_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/064f024583e9c1a7f0152f50aac1d16d_0.png
#
# Procesando image_name: 06691f5dc2caa5f72c05d4b26af810cf_0, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Encontrado DICOM para '06691f5dc2caa5f72c05d4b26af810cf' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/aba909f14c21dc68e13e516c8a8cbb7e/06691f5dc2caa5f72c05d4b26af810cf.dicom
# Imagen '06691f5dc2caa5f72c05d4b26af810cf_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/06691f5dc2caa5f72c05d4b26af810cf_0.png
#
# Procesando image_name: 06691f5dc2caa5f72c05d4b26af810cf_1, Categoría: Mass, BIRADS: BI-RADS 4
# Imagen '06691f5dc2caa5f72c05d4b26af810cf_1' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/06691f5dc2caa5f72c05d4b26af810cf_1.png
#
# Procesando image_name: 06691f5dc2caa5f72c05d4b26af810cf_2, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Imagen '06691f5dc2caa5f72c05d4b26af810cf_2' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/06691f5dc2caa5f72c05d4b26af810cf_2.png
#
# Procesando image_name: 06a407691cadae64cea5de8e8634a4ac_0, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Encontrado DICOM para '06a407691cadae64cea5de8e8634a4ac' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/dc8eca8e41cb72804147da33e91917bb/06a407691cadae64cea5de8e8634a4ac.dicom
# Imagen '06a407691cadae64cea5de8e8634a4ac_0' invertida debido a Photometric Interpretation: MONOCHROME1
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/06a407691cadae64cea5de8e8634a4ac_0.png
#
# Procesando image_name: 070170f7ee43d9304852fafdde498b05_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para '070170f7ee43d9304852fafdde498b05' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/3b15274e828c9c2c08e2bbc3a9ee5734/070170f7ee43d9304852fafdde498b05.dicom
# Imagen '070170f7ee43d9304852fafdde498b05_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/070170f7ee43d9304852fafdde498b05_0.png
#
# Procesando image_name: 0734a9dc7d6d89e8c91458545afeef9d_0, Categoría: Mass, BIRADS: BI-RADS 4
# Encontrado DICOM para '0734a9dc7d6d89e8c91458545afeef9d' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/268bbbd1932753cedf8846fe716c669b/0734a9dc7d6d89e8c91458545afeef9d.dicom
# Imagen '0734a9dc7d6d89e8c91458545afeef9d_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/0734a9dc7d6d89e8c91458545afeef9d_0.png
#
# Procesando image_name: 074775a9e94c93ed3ee32a82d2864c68_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para '074775a9e94c93ed3ee32a82d2864c68' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/70ea0d343edce93e2457df7a0e3cc9e2/074775a9e94c93ed3ee32a82d2864c68.dicom
# Imagen '074775a9e94c93ed3ee32a82d2864c68_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/074775a9e94c93ed3ee32a82d2864c68_0.png
#
# Procesando image_name: 074775a9e94c93ed3ee32a82d2864c68_1, Categoría: Mass, BIRADS: BI-RADS 3
# Imagen '074775a9e94c93ed3ee32a82d2864c68_1' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/074775a9e94c93ed3ee32a82d2864c68_1.png
#
# Procesando image_name: 07aef1389177ff428c1f78ef882e704f_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para '07aef1389177ff428c1f78ef882e704f' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/e40395270b091c226dc73cc9c6c2afe2/07aef1389177ff428c1f78ef882e704f.dicom
# Imagen '07aef1389177ff428c1f78ef882e704f_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/07aef1389177ff428c1f78ef882e704f_0.png
#
# Procesando image_name: 07e191bc54c3378f9fdf23ddecc47420_0, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Encontrado DICOM para '07e191bc54c3378f9fdf23ddecc47420' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/fa9226b8d31971dc665bf1f4066f8e59/07e191bc54c3378f9fdf23ddecc47420.dicom
# Imagen '07e191bc54c3378f9fdf23ddecc47420_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/07e191bc54c3378f9fdf23ddecc47420_0.png
#
# Procesando image_name: 07e191bc54c3378f9fdf23ddecc47420_1, Categoría: Mass, BIRADS: BI-RADS 4
# Imagen '07e191bc54c3378f9fdf23ddecc47420_1' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/07e191bc54c3378f9fdf23ddecc47420_1.png
#
# Procesando image_name: 07f468d6fff5b3e3b512e4b95cf0cdda_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para '07f468d6fff5b3e3b512e4b95cf0cdda' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/08ba91bb945c4dbc738b3f0a2e5798e6/07f468d6fff5b3e3b512e4b95cf0cdda.dicom
# Imagen '07f468d6fff5b3e3b512e4b95cf0cdda_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/07f468d6fff5b3e3b512e4b95cf0cdda_0.png
#
# Procesando image_name: 07f5863348560d0507bba86c8bba0586_0, Categoría: Mass, BIRADS: BI-RADS 4
# Encontrado DICOM para '07f5863348560d0507bba86c8bba0586' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/13429cc3bc880f9b40b45acbf9b1a2fb/07f5863348560d0507bba86c8bba0586.dicom
# Imagen '07f5863348560d0507bba86c8bba0586_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/07f5863348560d0507bba86c8bba0586_0.png
#
# Procesando image_name: 0806729f6ebeb658662051e8bdcfab3c_0, Categoría: Mass, BIRADS: BI-RADS 4
# Encontrado DICOM para '0806729f6ebeb658662051e8bdcfab3c' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/aba909f14c21dc68e13e516c8a8cbb7e/0806729f6ebeb658662051e8bdcfab3c.dicom
# Imagen '0806729f6ebeb658662051e8bdcfab3c_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/0806729f6ebeb658662051e8bdcfab3c_0.png
#
# Procesando image_name: 085915d953d1dcb1b70b6c3b8e68e1c5_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para '085915d953d1dcb1b70b6c3b8e68e1c5' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/a3f5fc2fc898d225bdacdc4083c37170/085915d953d1dcb1b70b6c3b8e68e1c5.dicom
# Imagen '085915d953d1dcb1b70b6c3b8e68e1c5_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/085915d953d1dcb1b70b6c3b8e68e1c5_0.png
#
# Procesando image_name: 08a64894ac411114c25dd709e2bcc471_0, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Encontrado DICOM para '08a64894ac411114c25dd709e2bcc471' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/44547b977313c66f106c07f99e492ee2/08a64894ac411114c25dd709e2bcc471.dicom
# Imagen '08a64894ac411114c25dd709e2bcc471_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/08a64894ac411114c25dd709e2bcc471_0.png
#
# Procesando image_name: 08a64894ac411114c25dd709e2bcc471_1, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Imagen '08a64894ac411114c25dd709e2bcc471_1' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/08a64894ac411114c25dd709e2bcc471_1.png
#
# Procesando image_name: 08a64894ac411114c25dd709e2bcc471_2, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Imagen '08a64894ac411114c25dd709e2bcc471_2' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/08a64894ac411114c25dd709e2bcc471_2.png
#
# Procesando image_name: 08a72a9160806b7b9334325d8870fa75_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para '08a72a9160806b7b9334325d8870fa75' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/b5567bec32bc168570b4189426bbc4e8/08a72a9160806b7b9334325d8870fa75.dicom
# Imagen '08a72a9160806b7b9334325d8870fa75_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/08a72a9160806b7b9334325d8870fa75_0.png
#
# Procesando image_name: 08fa2b8a39cb0bb6650a87dcad78b22f_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para '08fa2b8a39cb0bb6650a87dcad78b22f' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/7b1cea18dd875468cff8b957e23a82ec/08fa2b8a39cb0bb6650a87dcad78b22f.dicom
# Imagen '08fa2b8a39cb0bb6650a87dcad78b22f_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/08fa2b8a39cb0bb6650a87dcad78b22f_0.png
#
# Procesando image_name: 09025dbf5abd08828ecd4ebf03724341_0, Categoría: Suspicious Calcification, BIRADS: BI-RADS 5
# Encontrado DICOM para '09025dbf5abd08828ecd4ebf03724341' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/d8245da0e82b44954f356b5435d965d9/09025dbf5abd08828ecd4ebf03724341.dicom
# Imagen '09025dbf5abd08828ecd4ebf03724341_0' invertida debido a Photometric Interpretation: MONOCHROME1
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/maligno/09025dbf5abd08828ecd4ebf03724341_0.png
#
# Procesando image_name: 0939019fd916e0748e07d9546cd8bdf5_0, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Encontrado DICOM para '0939019fd916e0748e07d9546cd8bdf5' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/95cd59c69b542572baa1b2842b9c617d/0939019fd916e0748e07d9546cd8bdf5.dicom
# Imagen '0939019fd916e0748e07d9546cd8bdf5_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/0939019fd916e0748e07d9546cd8bdf5_0.png
#
# Procesando image_name: 096cc0a03198a6ee828e92b6eaed4e78_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para '096cc0a03198a6ee828e92b6eaed4e78' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/2109fb895eb5b829dd7c4f984ec7a954/096cc0a03198a6ee828e92b6eaed4e78.dicom
# Imagen '096cc0a03198a6ee828e92b6eaed4e78_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/096cc0a03198a6ee828e92b6eaed4e78_0.png
#
# Procesando image_name: 09c7c41323c29e418790f733ffb291c1_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para '09c7c41323c29e418790f733ffb291c1' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/da17728ab905a565051f16986aafda50/09c7c41323c29e418790f733ffb291c1.dicom
# Imagen '09c7c41323c29e418790f733ffb291c1_0' invertida debido a Photometric Interpretation: MONOCHROME1
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/09c7c41323c29e418790f733ffb291c1_0.png
#
# Procesando image_name: 09c7c41323c29e418790f733ffb291c1_1, Categoría: Mass, BIRADS: BI-RADS 3
# Imagen '09c7c41323c29e418790f733ffb291c1_1' invertida debido a Photometric Interpretation: MONOCHROME1
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/09c7c41323c29e418790f733ffb291c1_1.png
#
# Procesando image_name: 09e75ac07373f2e576fdcd909993b3bd_0, Categoría: Mass, BIRADS: BI-RADS 4
# Encontrado DICOM para '09e75ac07373f2e576fdcd909993b3bd' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/7264c672187822499817a15b5bb3ddb3/09e75ac07373f2e576fdcd909993b3bd.dicom
# Imagen '09e75ac07373f2e576fdcd909993b3bd_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/09e75ac07373f2e576fdcd909993b3bd_0.png
#
# Procesando image_name: 0a6f0eac805822cd00f3c25ba99569e8_0, Categoría: Mass, BIRADS: BI-RADS 5
# Encontrado DICOM para '0a6f0eac805822cd00f3c25ba99569e8' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/50a8bfda39adc93f22a174153632b823/0a6f0eac805822cd00f3c25ba99569e8.dicom
# Imagen '0a6f0eac805822cd00f3c25ba99569e8_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/maligno/0a6f0eac805822cd00f3c25ba99569e8_0.png
#
# Procesando image_name: 0aa8394efecbfb0f5c4a66ffbd215912_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para '0aa8394efecbfb0f5c4a66ffbd215912' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/7364e99bbbfc25fca6f398ca2110b55b/0aa8394efecbfb0f5c4a66ffbd215912.dicom
# Imagen '0aa8394efecbfb0f5c4a66ffbd215912_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/0aa8394efecbfb0f5c4a66ffbd215912_0.png
#
# Procesando image_name: 0abdf3f3255cb44a2a15908a811fe6e3_0, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Encontrado DICOM para '0abdf3f3255cb44a2a15908a811fe6e3' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/8c2c1cefe3ba30602b7249ad9ab5df07/0abdf3f3255cb44a2a15908a811fe6e3.dicom
# Imagen '0abdf3f3255cb44a2a15908a811fe6e3_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/0abdf3f3255cb44a2a15908a811fe6e3_0.png
#
# Procesando image_name: 0adb22b2b24d61c511acbe028648532e_0, Categoría: Mass, BIRADS: BI-RADS 4
# Encontrado DICOM para '0adb22b2b24d61c511acbe028648532e' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/540ab71b28752c3e279be9bad638df79/0adb22b2b24d61c511acbe028648532e.dicom
# Imagen '0adb22b2b24d61c511acbe028648532e_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/0adb22b2b24d61c511acbe028648532e_0.png
#
# Procesando image_name: 0b39adfdce0aafaa1ff02e9633e9cac5_0, Categoría: Suspicious Calcification, BIRADS: BI-RADS 3
# Encontrado DICOM para '0b39adfdce0aafaa1ff02e9633e9cac5' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/52bd2f2f2a70263495e7cce47c2ab229/0b39adfdce0aafaa1ff02e9633e9cac5.dicom
# Imagen '0b39adfdce0aafaa1ff02e9633e9cac5_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/benigno/0b39adfdce0aafaa1ff02e9633e9cac5_0.png
#
# Procesando image_name: 0b597a53d015b5d2c2df81f4c19eeea0_0, Categoría: Mass, BIRADS: BI-RADS 4
# Encontrado DICOM para '0b597a53d015b5d2c2df81f4c19eeea0' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/89e03e9698a3d7e9aceef0a5dc6da78b/0b597a53d015b5d2c2df81f4c19eeea0.dicom
# Imagen '0b597a53d015b5d2c2df81f4c19eeea0_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/0b597a53d015b5d2c2df81f4c19eeea0_0.png
#
# Procesando image_name: 0b597a53d015b5d2c2df81f4c19eeea0_1, Categoría: Mass, BIRADS: BI-RADS 5
# Imagen '0b597a53d015b5d2c2df81f4c19eeea0_1' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/maligno/0b597a53d015b5d2c2df81f4c19eeea0_1.png
#
# Procesando image_name: 0b873faadf6723e422e7ad7c1accc7c0_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para '0b873faadf6723e422e7ad7c1accc7c0' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/26571f2d2c8cc89e30059d05b4cabb1a/0b873faadf6723e422e7ad7c1accc7c0.dicom
# Imagen '0b873faadf6723e422e7ad7c1accc7c0_0' invertida debido a Photometric Interpretation: MONOCHROME1
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/0b873faadf6723e422e7ad7c1accc7c0_0.png
#
# Procesando image_name: 0b982200144c13b7302365e7f01c490d_0, Categoría: Mass, BIRADS: BI-RADS 4
# Encontrado DICOM para '0b982200144c13b7302365e7f01c490d' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/3d342bcea04ea881e47f9de7238f91ea/0b982200144c13b7302365e7f01c490d.dicom
# Imagen '0b982200144c13b7302365e7f01c490d_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/0b982200144c13b7302365e7f01c490d_0.png
#
# Procesando image_name: 0bac94530476031873566b909b8f1161_0, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Encontrado DICOM para '0bac94530476031873566b909b8f1161' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/9047f2eb0cda80c277bd169d6d240810/0bac94530476031873566b909b8f1161.dicom
# Imagen '0bac94530476031873566b909b8f1161_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/0bac94530476031873566b909b8f1161_0.png
#
# Procesando image_name: 0bb148da1406b21011529bb886c17e79_0, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Encontrado DICOM para '0bb148da1406b21011529bb886c17e79' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/2eddff9a90428070b98f85f4c4b6c758/0bb148da1406b21011529bb886c17e79.dicom
# Imagen '0bb148da1406b21011529bb886c17e79_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/0bb148da1406b21011529bb886c17e79_0.png
#
# Procesando image_name: 0bb148da1406b21011529bb886c17e79_1, Categoría: Mass, BIRADS: BI-RADS 5
# Imagen '0bb148da1406b21011529bb886c17e79_1' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/maligno/0bb148da1406b21011529bb886c17e79_1.png
#
# Procesando image_name: 0bcbcbbe010d72178ba66ded4ad519c4_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para '0bcbcbbe010d72178ba66ded4ad519c4' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/7364e99bbbfc25fca6f398ca2110b55b/0bcbcbbe010d72178ba66ded4ad519c4.dicom
# Imagen '0bcbcbbe010d72178ba66ded4ad519c4_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/0bcbcbbe010d72178ba66ded4ad519c4_0.png
#
# Procesando image_name: 0c19be554e27e2fdc2fe05ad954e825c_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para '0c19be554e27e2fdc2fe05ad954e825c' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/7e6403be5452b4fff44c3993aab88707/0c19be554e27e2fdc2fe05ad954e825c.dicom
# Imagen '0c19be554e27e2fdc2fe05ad954e825c_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/0c19be554e27e2fdc2fe05ad954e825c_0.png
#
# Procesando image_name: 0c401b1b7faaa89afc4a68983f074b16_0, Categoría: Mass, BIRADS: BI-RADS 5
# Encontrado DICOM para '0c401b1b7faaa89afc4a68983f074b16' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/d746c5e878799ec8f42e2e8f6ab9a992/0c401b1b7faaa89afc4a68983f074b16.dicom
# Imagen '0c401b1b7faaa89afc4a68983f074b16_0' invertida debido a Photometric Interpretation: MONOCHROME1
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/maligno/0c401b1b7faaa89afc4a68983f074b16_0.png
#
# Procesando image_name: 0c48ef2d25c7fe685e4a9d20b676c3a7_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para '0c48ef2d25c7fe685e4a9d20b676c3a7' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/0fbeb0c0568911d2e9508e1eca010a32/0c48ef2d25c7fe685e4a9d20b676c3a7.dicom
# Imagen '0c48ef2d25c7fe685e4a9d20b676c3a7_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/0c48ef2d25c7fe685e4a9d20b676c3a7_0.png
#
# Procesando image_name: 0c57e79ec6fc2ad0aa38ae8e2f54af07_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para '0c57e79ec6fc2ad0aa38ae8e2f54af07' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/9efd5f5c65ec8c402ec48f0ff7388562/0c57e79ec6fc2ad0aa38ae8e2f54af07.dicom
# Imagen '0c57e79ec6fc2ad0aa38ae8e2f54af07_0' invertida debido a Photometric Interpretation: MONOCHROME1
# ...
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/fad1035fa251f5f7fc318dea403aa7dc_0.png
#
# Procesando image_name: fae5f8cf37f37b672454a67ff7b16ef0_0, Categoría: Mass, BIRADS: BI-RADS 4
# Encontrado DICOM para 'fae5f8cf37f37b672454a67ff7b16ef0' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/4152e212d727057984702e2dfbdee234/fae5f8cf37f37b672454a67ff7b16ef0.dicom
# Imagen 'fae5f8cf37f37b672454a67ff7b16ef0_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/fae5f8cf37f37b672454a67ff7b16ef0_0.png
#
# Procesando image_name: fb16653152c4808c9e759888d15e42c4_0, Categoría: Mass, BIRADS: BI-RADS 5
# Encontrado DICOM para 'fb16653152c4808c9e759888d15e42c4' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/ad39689f1bea2e0aee2574488f06d231/fb16653152c4808c9e759888d15e42c4.dicom
# Imagen 'fb16653152c4808c9e759888d15e42c4_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/maligno/fb16653152c4808c9e759888d15e42c4_0.png
#
# Procesando image_name: fb37f7f1423480f1173ff376ca8e6ada_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para 'fb37f7f1423480f1173ff376ca8e6ada' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/f290c2c0bb608ab0287c35c4693696e6/fb37f7f1423480f1173ff376ca8e6ada.dicom
# Imagen 'fb37f7f1423480f1173ff376ca8e6ada_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/fb37f7f1423480f1173ff376ca8e6ada_0.png
#
# Procesando image_name: fb3eca52ff53f6b49df9ea75bf2b9dd7_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para 'fb3eca52ff53f6b49df9ea75bf2b9dd7' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/9b24b3af1eda9310f1a0d213d06001ab/fb3eca52ff53f6b49df9ea75bf2b9dd7.dicom
# Imagen 'fb3eca52ff53f6b49df9ea75bf2b9dd7_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/fb3eca52ff53f6b49df9ea75bf2b9dd7_0.png
#
# Procesando image_name: fb413cf6ef972090326d9886fa500aa2_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para 'fb413cf6ef972090326d9886fa500aa2' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/882d6a7db05470e51f85f3c77b217945/fb413cf6ef972090326d9886fa500aa2.dicom
# Imagen 'fb413cf6ef972090326d9886fa500aa2_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/fb413cf6ef972090326d9886fa500aa2_0.png
#
# Procesando image_name: fb70bcb1b4be4e6942a47e775b497aec_0, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Encontrado DICOM para 'fb70bcb1b4be4e6942a47e775b497aec' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/c626a17d9f6aa2a128d94d064819e60d/fb70bcb1b4be4e6942a47e775b497aec.dicom
# Imagen 'fb70bcb1b4be4e6942a47e775b497aec_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/fb70bcb1b4be4e6942a47e775b497aec_0.png
#
# Procesando image_name: fbe89362c0679ef85b12823a1a3fd3de_0, Categoría: Suspicious Calcification, BIRADS: BI-RADS 3
# Encontrado DICOM para 'fbe89362c0679ef85b12823a1a3fd3de' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/2f4d26ae21e1fb85ec2d97f9464aadff/fbe89362c0679ef85b12823a1a3fd3de.dicom
# Imagen 'fbe89362c0679ef85b12823a1a3fd3de_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/benigno/fbe89362c0679ef85b12823a1a3fd3de_0.png
#
# Procesando image_name: fc35547785ce94420408f99bbfad57fb_0, Categoría: Mass, BIRADS: BI-RADS 4
# Encontrado DICOM para 'fc35547785ce94420408f99bbfad57fb' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/2bdce0ce6edd00ac0c8400ec5ff790ea/fc35547785ce94420408f99bbfad57fb.dicom
# Imagen 'fc35547785ce94420408f99bbfad57fb_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/fc35547785ce94420408f99bbfad57fb_0.png
#
# Procesando image_name: fc6a348a61d4282a66ac2dc6dbec5981_0, Categoría: Suspicious Calcification, BIRADS: BI-RADS 5
# Encontrado DICOM para 'fc6a348a61d4282a66ac2dc6dbec5981' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/7fd8b8221c97ba86ff9cc98dcbd98fb8/fc6a348a61d4282a66ac2dc6dbec5981.dicom
# Imagen 'fc6a348a61d4282a66ac2dc6dbec5981_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/maligno/fc6a348a61d4282a66ac2dc6dbec5981_0.png
#
# Procesando image_name: fc6a348a61d4282a66ac2dc6dbec5981_1, Categoría: Mass, BIRADS: BI-RADS 5
# Imagen 'fc6a348a61d4282a66ac2dc6dbec5981_1' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/maligno/fc6a348a61d4282a66ac2dc6dbec5981_1.png
#
# Procesando image_name: fc869569babcc087c18d01ff23b27a18_0, Categoría: Mass, BIRADS: BI-RADS 5
# Encontrado DICOM para 'fc869569babcc087c18d01ff23b27a18' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/15a411e94e743361a5725ccf6b728ded/fc869569babcc087c18d01ff23b27a18.dicom
# Imagen 'fc869569babcc087c18d01ff23b27a18_0' invertida debido a Photometric Interpretation: MONOCHROME1
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/maligno/fc869569babcc087c18d01ff23b27a18_0.png
#
# Procesando image_name: fcfc75c0adef3f1491137de3f855d39c_0, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Encontrado DICOM para 'fcfc75c0adef3f1491137de3f855d39c' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/1a6eb4bb66e7e5a47d9191e0aa13930e/fcfc75c0adef3f1491137de3f855d39c.dicom
# Imagen 'fcfc75c0adef3f1491137de3f855d39c_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/fcfc75c0adef3f1491137de3f855d39c_0.png
#
# Procesando image_name: fd0c0b70adb9608b5b2dcf57f05668f3_0, Categoría: Mass, BIRADS: BI-RADS 4
# Encontrado DICOM para 'fd0c0b70adb9608b5b2dcf57f05668f3' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/973bd2de8e4dba021c5bcfa1086d0c2c/fd0c0b70adb9608b5b2dcf57f05668f3.dicom
# Imagen 'fd0c0b70adb9608b5b2dcf57f05668f3_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/fd0c0b70adb9608b5b2dcf57f05668f3_0.png
#
# Procesando image_name: fd3a1956f031a897741ae12ba7356b40_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para 'fd3a1956f031a897741ae12ba7356b40' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/59724bca2782a2642f92d7d21e973bef/fd3a1956f031a897741ae12ba7356b40.dicom
# Imagen 'fd3a1956f031a897741ae12ba7356b40_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/fd3a1956f031a897741ae12ba7356b40_0.png
#
# Procesando image_name: fde1086cce41c66b9efc68270f537837_0, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Encontrado DICOM para 'fde1086cce41c66b9efc68270f537837' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/58a2640209d9244ab1eca8f0686effd4/fde1086cce41c66b9efc68270f537837.dicom
# Imagen 'fde1086cce41c66b9efc68270f537837_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/fde1086cce41c66b9efc68270f537837_0.png
#
# Procesando image_name: fde1086cce41c66b9efc68270f537837_1, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Imagen 'fde1086cce41c66b9efc68270f537837_1' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/fde1086cce41c66b9efc68270f537837_1.png
#
# Procesando image_name: fde1086cce41c66b9efc68270f537837_2, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Imagen 'fde1086cce41c66b9efc68270f537837_2' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/fde1086cce41c66b9efc68270f537837_2.png
#
# Procesando image_name: fdef102a89845c81d40fa6c8869fb99a_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para 'fdef102a89845c81d40fa6c8869fb99a' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/1785f941abfc8ffc75be624d9e6d5f17/fdef102a89845c81d40fa6c8869fb99a.dicom
# Imagen 'fdef102a89845c81d40fa6c8869fb99a_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/fdef102a89845c81d40fa6c8869fb99a_0.png
#
# Procesando image_name: fe4273ea38a3028f91f80e5e12a84301_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para 'fe4273ea38a3028f91f80e5e12a84301' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/30531093985dd9b3d909c3866c46e443/fe4273ea38a3028f91f80e5e12a84301.dicom
# Imagen 'fe4273ea38a3028f91f80e5e12a84301_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/fe4273ea38a3028f91f80e5e12a84301_0.png
#
# Procesando image_name: ff1006f34fb13f42dff90aff81dc33ce_0, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Encontrado DICOM para 'ff1006f34fb13f42dff90aff81dc33ce' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/4598a7b538afcbf6d6f0d71fb654dacd/ff1006f34fb13f42dff90aff81dc33ce.dicom
# Imagen 'ff1006f34fb13f42dff90aff81dc33ce_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/ff1006f34fb13f42dff90aff81dc33ce_0.png
#
# Procesando image_name: ff1ac3371deae6d83a882e5ac36378e6_0, Categoría: Mass, BIRADS: BI-RADS 4
# Encontrado DICOM para 'ff1ac3371deae6d83a882e5ac36378e6' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/70c91262ab8842935e5569c4ea7cc20d/ff1ac3371deae6d83a882e5ac36378e6.dicom
# Imagen 'ff1ac3371deae6d83a882e5ac36378e6_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/ff1ac3371deae6d83a882e5ac36378e6_0.png
#
# Procesando image_name: ff476c753265aa0baa6685c58d5ef05a_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para 'ff476c753265aa0baa6685c58d5ef05a' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/775b952222e22629c94c0fa606118ab6/ff476c753265aa0baa6685c58d5ef05a.dicom
# Imagen 'ff476c753265aa0baa6685c58d5ef05a_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/ff476c753265aa0baa6685c58d5ef05a_0.png
#
# Procesando image_name: ff6716b4004598670fa72d8cefea454c_0, Categoría: Mass, BIRADS: BI-RADS 4
# Encontrado DICOM para 'ff6716b4004598670fa72d8cefea454c' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/fbfb4853334d90ff774ef326b8ac107b/ff6716b4004598670fa72d8cefea454c.dicom
# Imagen 'ff6716b4004598670fa72d8cefea454c_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/sospechoso/ff6716b4004598670fa72d8cefea454c_0.png
#
# Procesando image_name: ffac8bc2803630da2fb467c566d1f136_0, Categoría: Suspicious Calcification, BIRADS: BI-RADS 4
# Encontrado DICOM para 'ffac8bc2803630da2fb467c566d1f136' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/43420741f222a73d6d1c99ef63f79698/ffac8bc2803630da2fb467c566d1f136.dicom
# Imagen 'ffac8bc2803630da2fb467c566d1f136_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/calcificaciones/sospechoso/ffac8bc2803630da2fb467c566d1f136_0.png
#
# Procesando image_name: ffb94da823c87898c7ce19b197dc24c9_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para 'ffb94da823c87898c7ce19b197dc24c9' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/d35341b652a3b13e407358ea7a9b5f8f/ffb94da823c87898c7ce19b197dc24c9.dicom
# Imagen 'ffb94da823c87898c7ce19b197dc24c9_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/ffb94da823c87898c7ce19b197dc24c9_0.png
#
# Procesando image_name: ffe25766ac37ab145ae7f0bd78665f81_0, Categoría: Mass, BIRADS: BI-RADS 3
# Encontrado DICOM para 'ffe25766ac37ab145ae7f0bd78665f81' en subdirectorio: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc/5e738b21ece161aa495b59fee9c11455/ffe25766ac37ab145ae7f0bd78665f81.dicom
# Imagen 'ffe25766ac37ab145ae7f0bd78665f81_0' Photometric Interpretation: MONOCHROME2
# Imagen PNG guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG/masas/benigno/ffe25766ac37ab145ae7f0bd78665f81_0.png
#
# Nuevo CSV guardado en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/csv/png_masasycalcificaciones.csv
#
# Cantidad de imágenes por categoría y subcategoría:
# - Masas / Benigno: 566
# - Masas / Sospechoso: 453
# - Masas / Maligno: 104
# - Calcificaciones / Benigno: 65
# - Calcificaciones / Sospechoso: 284
# - Calcificaciones / Maligno: 53
#
# Total de imágenes procesadas: 1525
# Total de imágenes fallidas: 0

# %%
import os
import matplotlib.pyplot as plt
import cv2
import glob

# ---------------------- Configuración de Rutas ---------------------- #

# Ruta a la carpeta raíz donde se almacenan las imágenes PNG procesadas
output_root = '/Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc_PNG'

# Categorías y subcategorías
categories = {
    'masas': ['benigno', 'sospechoso', 'maligno'],
    'calcificaciones': ['benigno', 'sospechoso', 'maligno']
}

# ---------------------- Función para Seleccionar una Imagen ---------------------- #

def select_one_image(category, subcategory):
    """
    Selecciona la primera imagen PNG encontrada en la carpeta especificada.
    """
    # Construir la ruta de la subcategoría
    subcategory_path = os.path.join(output_root, category, subcategory)
    
    # Buscar archivos PNG en la carpeta
    png_files = glob.glob(os.path.join(subcategory_path, '*.png'))
    
    if png_files:
        return png_files[0]  # Retorna la primera imagen encontrada
    else:
        print(f"No se encontraron imágenes en {subcategory_path}")
        return None

# ---------------------- Visualización de Imágenes ---------------------- #

def visualize_images(categories):
    """
    Visualiza una imagen de cada combinación de categoría y subcategoría.
    """
    # Calcular el número total de subcategorías para la cuadrícula
    total_images = sum(len(subcats) for subcats in categories.values())
    
    # Configurar la figura de Matplotlib
    cols = 3  # Número de columnas en la cuadrícula
    rows = (total_images + cols - 1) // cols  # Calcular el número de filas necesarias
    
    plt.figure(figsize=(15, 5 * rows))  # Ajustar el tamaño según el número de filas
    
    img_count = 1  # Contador de imágenes
    
    for category, subcategories in categories.items():
        for subcategory in subcategories:
            img_path = select_one_image(category, subcategory)
            if img_path:
                # Leer la imagen usando OpenCV
                img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                if img is None:
                    print(f"Error al leer la imagen: {img_path}")
                    continue
                
                # Mostrar la imagen en la cuadrícula
                plt.subplot(rows, cols, img_count)
                plt.imshow(img, cmap='gray')
                plt.title(f"{category.capitalize()} / {subcategory.capitalize()}")
                plt.axis('off')  # Ocultar los ejes
                img_count += 1
    
    plt.tight_layout()
    plt.show()

# ---------------------- Ejecutar la Visualización ---------------------- #

if __name__ == "__main__":
    visualize_images(categories)
