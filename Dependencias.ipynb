# %%
# Suprimir las advertencias de pip
# !pip config set global.disable-pip-version-check true
# !pip config set global.root-user-action ignore

# Instalar PyTorch con soporte CUDA si tienes GPU
# !pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu118

# Instalar PyDicom para trabajar con archivos DICOM
# !pip install pydicom

# Instalar albumentations para las aumentaciones de imágenes
# !pip install albumentations

# Instalar timm para modelos preentrenados
# !pip install timm

# Instalar Torch-TensorRT para optimizar la inferencia en GPU (opcional)
# !pip install nvidia-pyindex
# !pip install torch-tensorrt -f https://github.com/NVIDIA/Torch-TensorRT/releases

# Instalar otras dependencias necesarias
# !pip install matplotlib opencv-python-headless scikit-learn

# Configuración de entorno CUDA
import os
os.environ['CUDA_MODULE_LOADING'] = 'LAZY'

print("Instalación de dependencias y configuración del entorno completada.")
# Out:
# Writing to /Library/Frameworks/Python.framework/Versions/3.12/pip.conf
# Writing to /Library/Frameworks/Python.framework/Versions/3.12/pip.conf
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com, https://download.pytorch.org/whl/cu118
# ...
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Looking in links: https://github.com/NVIDIA/Torch-TensorRT/releases
# ...
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [13 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
# ...

# %% [markdown]
# Supresión de advertencias de pip: Configura pip para que no muestre advertencias innecesarias, lo que ayuda a mantener la salida limpia.
#
# Instalación de PyTorch: Se instala PyTorch con soporte para CUDA, asegurando que puedas aprovechar la aceleración por GPU.
#
# Instalación de PyDicom: Esta librería es esencial para cargar y procesar archivos DICOM, que es el formato de las imágenes en tu dataset.
#
# Instalación de albumentations: Es una librería muy potente para aplicar aumentaciones a las imágenes, lo cual es crucial para mejorar la generalización del modelo.
#
# Instalación de timm: Permite acceder a una amplia gama de modelos preentrenados, como Convnext, que puedes utilizar para tu tarea de clasificación de imágenes médicas.
#
# Instalación de Torch-TensorRT: Si planeas optimizar la inferencia del modelo en GPU, esta librería te permitirá hacerlo. Es opcional, pero útil si trabajas con grandes volúmenes de datos o necesitas inferencia rápida.
#
# Instalación de otras dependencias: Incluye librerías comunes como matplotlib para visualización, opencv-python-headless para procesamiento de imágenes, y scikit-learn para evaluación y métricas.
#
# Configuración de entorno CUDA: Asegura que los módulos CUDA se carguen de manera eficiente.
