# %% [markdown]
# ### Este notebook generará los recortes de las imágenes de masas y calcificaciones

# %% [markdown]
# ### Método basado en el github "ConvNets for Detection of Abnormalities in Mammograms"
#
# #### Puntos clave de este método:
#
# - Método de Extracción Basado en el Centro de la ROI: En lugar de recortar directamente la ROI basada en las coordenadas xmin, ymin, xmax, ymax, este enfoque utiliza el centro de la ROI y añade un padding dinámico dependiendo del tamaño de la ROI. Esto permite extraer recortes más centrados, sin depender únicamente de los límites estrictos de la ROI original.
# Padding Dinámico:
#
# - Se aplica un padding del 20% si la ROI es más pequeña que el tamaño mínimo (598x598) y un padding del 5% si es mayor. Esto asegura que el área alrededor de la anomalía se incluya adecuadamente, independientemente de su tamaño, y ayuda a preservar el contexto anatómico.
# Uso de un Tamaño Mínimo de Recorte:
#
# - Se introduce el concepto de MIN_SIZE (598x598) para asegurarse de que el área de interés no se reduzca demasiado antes de hacer el recorte. Esto evita que las anomalías pequeñas se pierdan en el recorte y proporciona un área más amplia de contexto anatómico.
# Reducción de Artefactos en Recortes Pequeños:
#
# - Al no forzar el recorte directamente a las coordenadas exactas de la ROI, y en lugar de eso añadir padding basado en el tamaño de la ROI, este enfoque reduce el riesgo de introducir artefactos en imágenes pequeñas, lo que mejora la robustez del modelo cuando se trabaja con imágenes en bruto.

# %%
import os
import cv2
import pydicom
import numpy as np
import pandas as pd
from pydicom.pixel_data_handlers.util import apply_voi_lut

# Rutas al dataset y archivos
dicom_root = '/Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/Images_Mass_Calc'
csv_path = '/Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/csv/filtered_with_image_names.csv'
output_root = '/Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1'

# Crear carpetas principales (training y test)
train_folder = os.path.join(output_root, 'training')
test_folder = os.path.join(output_root, 'test')

os.makedirs(train_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)

# Crear carpetas de masas y calcificaciones, y sus subcarpetas (benigno, maligno, sospechoso) dentro de 'training' y 'test'
for split_folder in [train_folder, test_folder]:
    os.makedirs(os.path.join(split_folder, 'masas', 'benigno'), exist_ok=True)
    os.makedirs(os.path.join(split_folder, 'masas', 'maligno'), exist_ok=True)
    os.makedirs(os.path.join(split_folder, 'masas', 'sospechoso'), exist_ok=True)
    os.makedirs(os.path.join(split_folder, 'calcificaciones', 'benigno'), exist_ok=True)
    os.makedirs(os.path.join(split_folder, 'calcificaciones', 'maligno'), exist_ok=True)
    os.makedirs(os.path.join(split_folder, 'calcificaciones', 'sospechoso'), exist_ok=True)

# Tamaño objetivo al que queremos llegar para el recorte (similar a 299x299)
TARGET_SIZE = (299, 299)
MIN_SIZE = 598  # El tamaño objetivo para la imagen sin padding.

# Leer las anotaciones CSV que contienen las coordenadas de la ROI
ss1 = pd.read_csv(csv_path)

# Limpiar las categorías eliminando los caracteres adicionales
ss1['finding_categories'] = ss1['finding_categories'].apply(lambda x: x.strip("[]'"))

# Crear un DataFrame vacío para guardar las nuevas coordenadas
ss1_rescaled = pd.DataFrame(columns=ss1.columns)

# Función para obtener la ruta del archivo DICOM usando image_id
def get_dicom_path(image_id):
    for study_id in os.listdir(dicom_root):
        study_path = os.path.join(dicom_root, study_id)
        if os.path.isdir(study_path):
            dicom_path = os.path.join(study_path, image_id + '.dicom')
            if os.path.exists(dicom_path):
                return dicom_path
    raise FileNotFoundError(f"No se encontró el archivo DICOM para image_id: {image_id}")

# Función para aplicar el recorte basado en el centro de la ROI, con padding variable.
def extract_roi(image_name, split, birads, finding_categories, ss1_rescaled):
    # Obtener el image_id (parte antes del guión bajo "_")
    image_id = image_name.split('_')[0]
    dicom_path = get_dicom_path(image_id)

    # Leer la imagen DICOM
    dicom = pydicom.dcmread(dicom_path)
    original_image = dicom.pixel_array

    # Aplicar VOI LUT con prefer_lut=True (priorizando LUT si está presente)
    img_windowed = apply_voi_lut(original_image, dicom, prefer_lut=True)

    # Normalizar la imagen para que esté en el rango [0, 255]
    img_windowed = (img_windowed - img_windowed.min()) / (img_windowed.max() - img_windowed.min()) * 255
    img_windowed = img_windowed.astype(np.uint8)

    # Extraer las coordenadas de la ROI desde el CSV utilizando el image_name
    try:
        x1, y1 = (int(ss1.loc[ss1['image_name'] == image_name, 'xmin'].values[0]),
                  int(ss1.loc[ss1['image_name'] == image_name, 'ymin'].values[0]))
        x2, y2 = (int(ss1.loc[ss1['image_name'] == image_name, 'xmax'].values[0]),
                  int(ss1.loc[ss1['image_name'] == image_name, 'ymax'].values[0]))
    except IndexError:
        print(f"Error: No se encontraron coordenadas para la ROI de la imagen {image_name}.")
        return ss1_rescaled

    # Verificar que las coordenadas sean válidas
    x1 = max(0, x1)
    y1 = max(0, y1)
    x2 = min(img_windowed.shape[1], x2)
    y2 = min(img_windowed.shape[0], y2)
    
    # Calcular el centro de la ROI
    center_x = (x1 + x2) // 2
    center_y = (y1 + y2) // 2

    # Determinar el tamaño de la ROI original
    width = x2 - x1
    height = y2 - y1

    # Agregar padding variable según el tamaño de la ROI
    if width < MIN_SIZE or height < MIN_SIZE:
        # ROI es más pequeña que el tamaño objetivo, añadimos padding (20%)
        padding_x = int(width * 0.2)
        padding_y = int(height * 0.2)
    else:
        # ROI es mayor, añadimos menos padding (5%)
        padding_x = int(width * 0.05)
        padding_y = int(height * 0.05)

    # Establecer los nuevos límites de la imagen recortada, con padding
    x1_new = max(center_x - (MIN_SIZE // 2) - padding_x, 0)
    y1_new = max(center_y - (MIN_SIZE // 2) - padding_y, 0)
    x2_new = min(center_x + (MIN_SIZE // 2) + padding_x, img_windowed.shape[1])
    y2_new = min(center_y + (MIN_SIZE // 2) + padding_y, img_windowed.shape[0])

    # Recortar la imagen utilizando las nuevas coordenadas ajustadas
    crop = img_windowed[y1_new:y2_new, x1_new:x2_new]

    # Verificar si el recorte no está vacío
    if crop.size == 0:
        print(f"Error: El recorte para la imagen {image_name} está vacío.")
        return ss1_rescaled

    # Redimensionar el recorte a 299x299 píxeles
    try:
        crop_resized = cv2.resize(crop, TARGET_SIZE)
    except cv2.error as e:
        print(f"Error al redimensionar el recorte para la imagen {image_name}: {e}")
        return ss1_rescaled

    # Calcular las nuevas coordenadas reescaladas
    scale_x = TARGET_SIZE[0] / crop.shape[1]
    scale_y = TARGET_SIZE[1] / crop.shape[0]

    xmin_rescaled = int((x1 - x1_new) * scale_x)
    ymin_rescaled = int((y1 - y1_new) * scale_y)
    xmax_rescaled = int((x2 - x1_new) * scale_x)
    ymax_rescaled = int((y2 - y1_new) * scale_y)

    # Ajuste en el split: manejar 'train', 'training' y 'test'
    if split in ['train', 'training']:
        base_dir = train_folder
    elif split == 'test':
        base_dir = test_folder
    else:
        print(f"Error: Split desconocido '{split}' para la imagen {image_name}.")
        return ss1_rescaled

    # Verificar si se asigna una categoría válida a la variable output_dir
    if finding_categories == 'Mass':
        output_dir = os.path.join(base_dir, 'masas')
    elif finding_categories == 'Suspicious Calcification':
        output_dir = os.path.join(base_dir, 'calcificaciones')
    else:
        print(f"Error: Categoría desconocida '{finding_categories}' para la imagen {image_name}.")
        return ss1_rescaled

    # Categorizar en benigno, maligno, o sospechoso según el valor de BIRADS
    if birads == 'BI-RADS 3':
        output_dir = os.path.join(output_dir, 'benigno')
    elif birads == 'BI-RADS 5':
        output_dir = os.path.join(output_dir, 'maligno')
    elif birads == 'BI-RADS 4':
        output_dir = os.path.join(output_dir, 'sospechoso')
    else:
        print(f"Error: BIRADS desconocido '{birads}' para la imagen {image_name}.")
        return ss1_rescaled

    # Guardar la imagen recortada con el formato {image_name}.png
    roi_filename = f"{image_name}.png"
    output_path = os.path.join(output_dir, roi_filename)
    cv2.imwrite(output_path, crop_resized)
    print(f"Imagen ROI guardada en: {output_path}")

    # Guardar las coordenadas reescaladas en el nuevo CSV
    new_row = ss1.loc[ss1['image_name'] == image_name].copy()
    new_row['xmin'] = xmin_rescaled
    new_row['ymin'] = ymin_rescaled
    new_row['xmax'] = xmax_rescaled
    new_row['ymax'] = ymax_rescaled
    ss1_rescaled = pd.concat([ss1_rescaled, new_row], ignore_index=True)

    return ss1_rescaled

# Función para recorrer todas las imágenes del CSV y guardar las ROI redimensionadas y las nuevas coordenadas
def process_all_images():
    global ss1_rescaled
    for _, row in ss1.iterrows():
        image_name = row['image_name']
        split = row['split']  # La columna 'split' tiene los valores 'train', 'training', o 'test'
        birads = row['finding_birads']  # Columna con los valores BIRADS
        finding_categories = row['finding_categories']  # Columna con el tipo de hallazgo (mass o suspicious)

        # Procesar cada imagen y almacenar las ROI y coordenadas reescaladas
        ss1_rescaled = extract_roi(image_name, split, birads, finding_categories, ss1_rescaled)

    # Guardar el nuevo CSV con las coordenadas reescaladas
    new_csv_path = '/Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/csv/CROP1.csv'
    ss1_rescaled.to_csv(new_csv_path, index=False)
    print(f"Nuevo CSV guardado en: {new_csv_path}")

# Ejecutar el procesamiento de todas las imágenes
process_all_images()
# Out:
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/001ade2a3cb53fd808bd2856a0df5413_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/001ade2a3cb53fd808bd2856a0df5413_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/001ade2a3cb53fd808bd2856a0df5413_2.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/002074412a8fc178c271fb93b55c3e29_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/002460132586dc0c7b88a59dce6e77bd_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/calcificaciones/sospechoso/00857417d07096982013956033da1f75_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/008c66563c73b2f5b8e42915b2cd6af5_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/00be38a5c0566291168fe381ba0028e6_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/00ec2be128f964da6f0b0ba179c4d138_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/maligno/013e4b7bcdaf536c4e37b4125ab8148b_0.png
# /var/folders/ds/4z7lc9ld4mqb377_3t2v4lxm0000gn/T/ipykernel_9115/3338577261.py:174: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ss1_rescaled = pd.concat([ss1_rescaled, new_row], ignore_index=True)
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/0171ab32059f4c226164a13c311f6824_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/sospechoso/01958718afdf303581e758cdf34eaf8a_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/maligno/01df962b078e38500bf9dd9969a50083_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/01fb871dc222684a9950609b62b76772_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/02895cbbcb504f54c6882c4c5695f563_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/calcificaciones/sospechoso/02b3206d267eb7f354113b0c5365127b_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/02d253f51556e2e0af63525de2e9ff74_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/02d253f51556e2e0af63525de2e9ff74_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/02d253f51556e2e0af63525de2e9ff74_2.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/031592807c30b54e2fb4bd2400e634e8_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/032ab9e0ecd5fd673517ffa3eb805d15_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/sospechoso/03674edf018ba8eef3c2857d1aa3305b_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/maligno/03b3656c726cbe0d79c86a25d4296559_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/03b3656c726cbe0d79c86a25d4296559_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/03e464754732750f5828aeb94af68b22_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/040cc172596bded4092c44094dc33fb7_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/0426e31fea8079ce30b796c80321a17c_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/042733688eecb852ea06140448a8b1bf_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/04c64dd7683662188094816c7c2ca88d_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/050c2f6caf47f439d62e1fc8942396f6_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/051525b959eefb14e973acc7ab8fcfe0_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/0602173c47d1b21fe548b2d852433a03_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/0602173c47d1b21fe548b2d852433a03_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/06073969e7453f71ac8108c6081dc9b8_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/061bc49a16cad3bc2b479993f7e689f8_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/061bf98fabad5f9d99fb1919346a3a76_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/061bf98fabad5f9d99fb1919346a3a76_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/061c11537a514e894a296a7d72064a90_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/064f024583e9c1a7f0152f50aac1d16d_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/06691f5dc2caa5f72c05d4b26af810cf_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/06691f5dc2caa5f72c05d4b26af810cf_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/06691f5dc2caa5f72c05d4b26af810cf_2.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/06a407691cadae64cea5de8e8634a4ac_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/070170f7ee43d9304852fafdde498b05_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/sospechoso/0734a9dc7d6d89e8c91458545afeef9d_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/074775a9e94c93ed3ee32a82d2864c68_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/074775a9e94c93ed3ee32a82d2864c68_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/07aef1389177ff428c1f78ef882e704f_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/07e191bc54c3378f9fdf23ddecc47420_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/07e191bc54c3378f9fdf23ddecc47420_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/07f468d6fff5b3e3b512e4b95cf0cdda_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/07f5863348560d0507bba86c8bba0586_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/0806729f6ebeb658662051e8bdcfab3c_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/085915d953d1dcb1b70b6c3b8e68e1c5_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/08a64894ac411114c25dd709e2bcc471_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/08a64894ac411114c25dd709e2bcc471_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/08a64894ac411114c25dd709e2bcc471_2.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/08a72a9160806b7b9334325d8870fa75_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/08fa2b8a39cb0bb6650a87dcad78b22f_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/maligno/09025dbf5abd08828ecd4ebf03724341_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/0939019fd916e0748e07d9546cd8bdf5_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/096cc0a03198a6ee828e92b6eaed4e78_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/09c7c41323c29e418790f733ffb291c1_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/09c7c41323c29e418790f733ffb291c1_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/09e75ac07373f2e576fdcd909993b3bd_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/maligno/0a6f0eac805822cd00f3c25ba99569e8_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/0aa8394efecbfb0f5c4a66ffbd215912_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/0abdf3f3255cb44a2a15908a811fe6e3_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/sospechoso/0adb22b2b24d61c511acbe028648532e_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/benigno/0b39adfdce0aafaa1ff02e9633e9cac5_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/0b597a53d015b5d2c2df81f4c19eeea0_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/maligno/0b597a53d015b5d2c2df81f4c19eeea0_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/0b873faadf6723e422e7ad7c1accc7c0_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/0b982200144c13b7302365e7f01c490d_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/0bac94530476031873566b909b8f1161_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/0bb148da1406b21011529bb886c17e79_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/maligno/0bb148da1406b21011529bb886c17e79_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/0bcbcbbe010d72178ba66ded4ad519c4_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/0c19be554e27e2fdc2fe05ad954e825c_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/maligno/0c401b1b7faaa89afc4a68983f074b16_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/0c48ef2d25c7fe685e4a9d20b676c3a7_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/0c57e79ec6fc2ad0aa38ae8e2f54af07_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/maligno/0cf9cd3d36a7bfb95e66c0ba482eb8c0_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/maligno/0cf9cd3d36a7bfb95e66c0ba482eb8c0_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/maligno/0cf9cd3d36a7bfb95e66c0ba482eb8c0_2.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/0d0826dc6e633a7729ea56fa7390c508_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/0d08356a2638c214fbc6cbeb24251c0c_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/0d0c76cf04069b224806e8d8d3a9351b_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/0d58856b402c571d3fa0fc19d26267ca_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/0d58856b402c571d3fa0fc19d26267ca_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/calcificaciones/sospechoso/0d6987fc066d2fad238b5c15f4e9bf8e_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/0d818b48634b775f4c15cc0dd8a56b69_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/0d9de2c106f154c469b0d0b05980fb5e_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/0d9de2c106f154c469b0d0b05980fb5e_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/0dac8664468ff3ab7a3e24fda8053cf6_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/0dbc1663eceef924f0f339604af18364_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/0dbc1663eceef924f0f339604af18364_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/0dbc1663eceef924f0f339604af18364_2.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/maligno/0dbc1663eceef924f0f339604af18364_3.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/maligno/0dc38f7b2936fff46ec10a0beb5aaeb2_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/0de15bbc9f84e965d634e2bc686d11f1_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/0e188b766ff729c0332e3f49599d2796_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/0e31855d02eadf8670ffaeeaeddbf229_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/0e3db7bbea14c6dd5dbab7b95bfe82e4_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/0e9481c18a33d55b1fa0a353f53e0d6a_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/0f0009a94c664c2b67ae78fd675f323c_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/0f0009a94c664c2b67ae78fd675f323c_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/0f22280d1836afa323f2023d12be9573_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/0f3a1f45d84cbe6b77b3e9354bb9ea1a_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/0f5457dbb9449aa73bb9cf62e1c10847_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/0f714f0b91dcd0ff05a60290440d1004_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/0fb063fe3b46db2bbe83d124a3793101_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/sospechoso/100f9f1f5392774416f1a1e66a5a4c71_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/maligno/10e0f362333df810ac84a9db8fb3fd42_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/10e3136f3e11277d87ce71d123f7ba68_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/115600671e989b2ffeaac92d19d1f505_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/calcificaciones/sospechoso/11b8d57615519367276e766b61684f04_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/sospechoso/11b8d57615519367276e766b61684f04_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/11b953e33bdaee7933f8d1db574942af_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/calcificaciones/sospechoso/11d1c20d269f487d47fa5fc80c6f7722_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/calcificaciones/sospechoso/11dbf2405e94335db8d8011db532a5ac_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/12284c56ca4887b1747c1f45bce853f1_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/12284c56ca4887b1747c1f45bce853f1_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/12284c56ca4887b1747c1f45bce853f1_2.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/1297fb4b53170324f0f6eeaf74c4449c_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/1297fb4b53170324f0f6eeaf74c4449c_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/129b633979a43461369df710e69e111d_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/132095e759b34fba0adcba4205e1b513_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/13be6c55646212a038555d19e9f9c086_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/13dcce4e628d544820e41c43275b7806_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/benigno/13ea2c59ed904bde1da93f3160edb462_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/13eaf76f8ddd04c74b0215255afbb2e3_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/benigno/1407cdbe965eb744aa05018b37923ba3_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/calcificaciones/sospechoso/14387f59b61cfdebf1fc0ac124efaf6d_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/1507cf98ea325351b0104cb854a6ac83_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/150cb5d7fd49a32058caaa51714e8cd0_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/calcificaciones/sospechoso/1513f5d691d471605b882f111d388d46_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/benigno/15206c1ba3b120b11296ea2967afd6c0_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/maligno/153e6a233a6694e96db4356a947c9678_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/1545d3528b9cc99bcdf09d4b2b434f59_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/maligno/1545d3528b9cc99bcdf09d4b2b434f59_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/1545d3528b9cc99bcdf09d4b2b434f59_2.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/maligno/15c8e59fdfafb3deefc80c5a9e8a42d0_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/15f2e36521ccae32ee5ba13db9a8c02d_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/15fc491b06ef82774b6b8fc6ab09ef23_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/16772df2fc68173354ed7b5684e40a56_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/maligno/16772df2fc68173354ed7b5684e40a56_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/169b1fe3b0a21d269af8971754e3fa7d_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/16a7ae04fb0ec0039afbceb6c920906f_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/16c5567c9a2c621c980a8992f6540c01_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/17127fbc6f1c700106b7ec6725012007_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/175c9ad9cb031644884079a42f660dfc_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/1776d1586b4c7d8cc13c98309c5327df_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/maligno/1776d1586b4c7d8cc13c98309c5327df_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/17c9d5489c19c75ed3cb4032ba49afb7_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/17d2f5831c5cecb238f512e28f0277d7_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/17d91701b085d4cb0ae1c7b1c0af2bb1_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/185d72636122b93911abdbe015985e40_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/18636a03282a86b92f6593607cfce29f_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/18b6303a3ede8d3556f87dada8d64c49_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/19056b152c5d2ed98f66de006fa45a6c_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/19189466123f991dfd57d7b963c9c908_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/19269b87da23b12053b3bfcfa65a2eeb_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/maligno/19269b87da23b12053b3bfcfa65a2eeb_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/calcificaciones/sospechoso/194b24263d11adc0128da9953588359c_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/1966916e0825ec690dd32e51f30714e0_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/19aa7e28743b204e978558c4fed12fd2_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/19c0ecd06984b4d4b2c46812e85a06e6_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/maligno/19c0ecd06984b4d4b2c46812e85a06e6_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/19d9dd9f34f4b4cb14d584a38fe02151_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/sospechoso/1a1d13244aaafa6a12988c4e1d3efe5b_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/calcificaciones/benigno/1a1d13244aaafa6a12988c4e1d3efe5b_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/benigno/1a52264b19da38964392d40a72362fdd_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/1a6fc2d6c56e6b1b45d348df8c63c511_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/1a726ea772cfde63af2de1d9d1fba472_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/sospechoso/1a89e1a41d82efe8826ffe15c41db3f4_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/1b1463c42b11eb981faa5259f2c7b896_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/1b26a908ba95c2e63e58f1a44d5a3490_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/1b3ea2ffe5dc67d51c493ef22faed9e3_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/1bad693bff15cd631e84f1cfc717f3bb_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/1bc0bb5082b6f20d9dea0014ae5276db_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/1c1b9f28c515819a9eb5191e36709d8f_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/1c35cb30f776b18ab35a12deae0845b9_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/1c77399720e266b2124c6151b7bec82b_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/1c77399720e266b2124c6151b7bec82b_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/calcificaciones/sospechoso/1cbc0ae5d67abccd58a4ba6d657d921e_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/1cfb1d7f513466d8ca7900c23346d309_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/benigno/1d136d5f293069a1f77f544cf0f8265b_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/1d51d5bd22846821409cb531a95979d2_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/1d605d35628064e2f14c0f629b34459d_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/sospechoso/1d6b62c0ca67fccea012daed532bb9fc_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/1dda87c5adb8efb52c1e559ea4cabf54_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/1df290db9b7769fabaddab943891889d_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/1dfc7b08356eb6265b16a51a1ea208b1_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/1e074d67076ab3ccbcb6fabb7a93e479_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/1e2d94424f5a9a847f1a7e8eae1ecdd7_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/1e6d951c061c1e68ca0056aa7af70405_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/1e6d951c061c1e68ca0056aa7af70405_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/1e7ad5577c2f5e49294f9c3660968910_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/1eaafc26e519dcbb2f561902d3b6af85_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/1edafb4bb142562da9c6d0ebba585b83_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/1edfbc7b48a507046042a9961755af6a_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/sospechoso/1f2ad3de97b6d7a4d8f78af09c11b580_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/sospechoso/1f2ad3de97b6d7a4d8f78af09c11b580_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/1f4905d08a4a71d7791c775fcde2014b_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/1f4e4c2039476a9884bdd84c20d1484f_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/1f7105d923abab8db6a92eaa796dea1b_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/benigno/1f741efcce7da5f4fcc10378eeeab159_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/1fbf74aa3e9be948b0e9b1e73f8b3a9b_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/1fdb46d59513d90e8e1750799d9f8d03_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/1ffb933b38767a155e5afc94d852bd5b_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/1ffb933b38767a155e5afc94d852bd5b_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/202d1c29785f6327985ffda7100e2265_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/benigno/20ac518bf6370bc7c2b1adcf7377def8_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/benigno/20b4b2c70e6c4e1d4ab6d1b9b9be5308_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/sospechoso/20e22b55458ddc1002871f0b10bc0c91_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/calcificaciones/sospechoso/212bc03533346819d0c6d449d631f69f_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/215186ee75b38c34499cd0ebadc7ed20_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/2167f4da549862d60f43782cd38fb8ae_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/216d7c52e6a86ab26e19b06dac26351c_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/sospechoso/21a78229489f5b35b0b037f678a5cac4_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/223646dfc19e2605828b0262bc68a4db_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/sospechoso/2239d320d35b1d7ee84c9ad5bc692096_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/maligno/225863035d1c03f3c1cd49f409870fde_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/22fba1258f27256a9f1d090b0ddca9c7_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/22fba1258f27256a9f1d090b0ddca9c7_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/calcificaciones/sospechoso/230d88855d53b8edfb4c3cc7ef1248db_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/calcificaciones/sospechoso/230d88855d53b8edfb4c3cc7ef1248db_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/calcificaciones/sospechoso/230d88855d53b8edfb4c3cc7ef1248db_2.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/230e0069cf6710f68b38e0e4ec59a4e4_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/calcificaciones/sospechoso/2311c127704c6b0cf325d4da697d2b26_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/232d42e92fc9445b6e882d8391c3c782_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/232f33051c77bd6ce2d185aafe9471a3_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/233ca7084a75a79608f0225653bf0d83_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/23edfe4412bf14c73110dec6fdd9e66b_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/2424a42cd4c30fdb50d63a044055b1ee_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/2424a42cd4c30fdb50d63a044055b1ee_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/maligno/242f2cd03a6af087a5d1d7a9a9d3d764_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/242f2cd03a6af087a5d1d7a9a9d3d764_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/24554a4f939d8c4ec6f710ac98385407_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/2461b5dd3a59b501aaea002ab61050f5_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/sospechoso/248979f8c341862b99d2ab1e40a4efb1_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/benigno/24b3529f050a56afb384b30520bc8482_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/maligno/24f2397626a9dd77844c30af11d352f0_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/2524b3039b9f14943744db0d3d8e34dc_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/2530e73814b6a250140fab195ac789cc_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/255f0dcc5ca3131051e5fc06af99fca9_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/264233e448f4ac70a925dca6d1bfb64e_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/264233e448f4ac70a925dca6d1bfb64e_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/264d5e05c5774d9770eaf74c0483bd50_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/benigno/2671a2eff9d050a10d8bebe42e4c9cb9_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/26b97f0b7e0c45b51a4a26a0390168e0_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/maligno/26cc531e126e10d88eec413dcf0a4963_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/benigno/26dd42f1a4341cdf6feebd22564f8939_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/26eff7e7822b45d98c11fc3e51b46277_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/maligno/271e8bfd46adee65f8580092753d08e5_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/calcificaciones/maligno/27d9bf4e5b772624325d6232ffc8378a_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/27fdb282ea9e69942db9b9917472932d_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/283a13f9619b6177a7c389ca6685d715_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/28dcd7a3b2b76e57eec7de8884ca94dc_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/28df19fab3181eeb9dfcc55be3210f8a_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/2909023cb8470072de9368a7b88f17de_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/293f56aa2f38c52c70ed4a92e2f01b46_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/293f56aa2f38c52c70ed4a92e2f01b46_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/sospechoso/29409efa3402b9d8f044f04308b5d2d7_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/maligno/2973bcf878fad1e9edade25be62602ce_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/298aba8110e3e2667be23e7f8d188f44_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/2a04163be4ae7d6f70732904202cc934_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/2a67cf5f900de22b0c45fb2c1d55dba4_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/2ad344496bc6f2d91c27f501be133971_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/2b0eb970545cbf5906c79da0ee8ab1d6_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/2b217e87073f6ea171ab6d5e2034aae3_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/2b46a6fc2c076cfc187b385f6a6f40e6_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/2b46a6fc2c076cfc187b385f6a6f40e6_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/2b5cec9cad04a6c5eaf1cd2ec2e7a6f2_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/2b76a18e45c8e62db919403c6c526ec4_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/2bb31d34320c4d1005371802dcac319c_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/2bbe58aab434b2a6af7e873ca9adc56d_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/2bc1c6df1d38102593cdbc50610d2010_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/benigno/2bc80ebd58505c88bf1fc81b72c4fa42_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/2c57ca33256d3d97b905ef932f8ba268_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/2c9849db92a18f7cbeb2aed9d5d3ca07_0.png
# ...
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/sospechoso/f0e839f095171073b5348bb756afb32f_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/calcificaciones/maligno/f0f3808a479ac5e71f07084bcac83c68_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/f1097a8a50765e2261af176d00347cf0_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/f1097a8a50765e2261af176d00347cf0_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/f1301e728ee3553f3a701c15e64ea041_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/f13af0df8b6fdeecca7e36affeb56988_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/f17d87b660e35d32339d60cd3fb556b0_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/f17d87b660e35d32339d60cd3fb556b0_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/f17d87b660e35d32339d60cd3fb556b0_2.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/f17d87b660e35d32339d60cd3fb556b0_3.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/f1b0fbd4eebff392ed4b9886034c29ca_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/f1b0fbd4eebff392ed4b9886034c29ca_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/f1b0fbd4eebff392ed4b9886034c29ca_2.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/f1b0fbd4eebff392ed4b9886034c29ca_3.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/f1bfdcca5002d093e4b07e0099e252ec_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/f1dd8037a1a5f684cebc10a22e2e2797_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/f1f79501410a98782c0a03b48e66df83_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/f2504628e2a4c5e04bb39655b4776f57_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/f2a755158e2f2f4af7d1f8b6257893f5_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/f2a755158e2f2f4af7d1f8b6257893f5_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/sospechoso/f2d214b69a7661d43e755f8921706206_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/f2ebfa37e63f0aa3306b4cfdd4c7a18c_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/f2ebfa37e63f0aa3306b4cfdd4c7a18c_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/f3a4d89c558db44c3f9d81c07206a90e_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/f3b7da5f9ca3b14e89f6a66b7d1c2ef0_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/maligno/f3dee44f17d451479bf163107dbb9cf4_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/f448ee036cf84e001c689b24b05cf96c_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/f4ba658d56e0d50cb0093fa1052e1972_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/f502474200958c14accc60cd2d319ccf_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/f50d531553d2958b575c4f5bb7141b17_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/f51e0c5db5201a2cf58b424437007197_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/f54b07517cb46e8a59c1c10748bdb5ed_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/maligno/f54b07517cb46e8a59c1c10748bdb5ed_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/f56a57a109aed21840b83c8453e06a6e_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/f5b9c502a087f77d0606b0291a2e0606_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/maligno/f60e4a6ab3f58f13e178fe8d98e532c5_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/f6b19e19ebc1302afc17c9a3140a4ae9_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/f6c7f3c3e03d612002800f20b1282309_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/f75e7aff7268ba2e462c284e30cfc5b5_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/f78853b3aa2445fb60d677f6f5d82ca7_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/f7cdf7b22955e66d34cc1efccdab5fbf_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/sospechoso/f7d9acd8e1f576d801c24f90ad5a99d3_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/f8b75219cf050a795846c2772fad3e94_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/f8bbdcf948609aea0b384583364379e5_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/f8bbdcf948609aea0b384583364379e5_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/f8bbdcf948609aea0b384583364379e5_2.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/maligno/f8bfea7bae6392d0db67fddb39dcee32_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/f909934b0d96d977fffee6ee0777a1a7_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/f90d9c5b3c032980a35d7bface8e8fd4_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/f90ec8e52522a65d1c0c9f999837cc6c_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/f910a580645aee0ea0147a66c27c6fbf_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/sospechoso/f978cb9d32a74171873fb280779aa37f_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/f97cd5b8d0049cbceda56350c01a66d5_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/f97cd5b8d0049cbceda56350c01a66d5_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/f9918b3feb92e1f38a0c86a6a28c14a0_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/f99e08afa8e94624cc4e4d71b272c44d_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/f9a54449757586583a8f36ccc821f7ac_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/maligno/fa0104443e2e60effcb1e0222a9b015d_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/fa0104443e2e60effcb1e0222a9b015d_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/fa0d61ab7e2e1115fa871ff94d457d9b_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/fa2f7816bf1b07f2104aa4edeff9b107_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/fa4f9cc52819bd2aa35c57ad8a83113a_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/fa62bfb18ecd5fe37a4cc21b957a4eed_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/fa81d6994805601937dd950bca2e61a0_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/fa8e8eee66d4b88a869e9ced96a2238f_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/benigno/fabc21b31c91a6f8b0900a6767d46515_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/fabc21b31c91a6f8b0900a6767d46515_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/fad1035fa251f5f7fc318dea403aa7dc_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/fae5f8cf37f37b672454a67ff7b16ef0_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/maligno/fb16653152c4808c9e759888d15e42c4_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/fb37f7f1423480f1173ff376ca8e6ada_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/fb3eca52ff53f6b49df9ea75bf2b9dd7_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/fb413cf6ef972090326d9886fa500aa2_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/fb70bcb1b4be4e6942a47e775b497aec_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/benigno/fbe89362c0679ef85b12823a1a3fd3de_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/fc35547785ce94420408f99bbfad57fb_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/maligno/fc6a348a61d4282a66ac2dc6dbec5981_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/maligno/fc6a348a61d4282a66ac2dc6dbec5981_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/maligno/fc869569babcc087c18d01ff23b27a18_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/calcificaciones/sospechoso/fcfc75c0adef3f1491137de3f855d39c_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/fd0c0b70adb9608b5b2dcf57f05668f3_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/fd3a1956f031a897741ae12ba7356b40_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/fde1086cce41c66b9efc68270f537837_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/fde1086cce41c66b9efc68270f537837_1.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/fde1086cce41c66b9efc68270f537837_2.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/fdef102a89845c81d40fa6c8869fb99a_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/fe4273ea38a3028f91f80e5e12a84301_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/calcificaciones/sospechoso/ff1006f34fb13f42dff90aff81dc33ce_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/sospechoso/ff1ac3371deae6d83a882e5ac36378e6_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/benigno/ff476c753265aa0baa6685c58d5ef05a_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/test/masas/sospechoso/ff6716b4004598670fa72d8cefea454c_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/calcificaciones/sospechoso/ffac8bc2803630da2fb467c566d1f136_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/ffb94da823c87898c7ce19b197dc24c9_0.png
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1/training/masas/benigno/ffe25766ac37ab145ae7f0bd78665f81_0.png
# Nuevo CSV guardado en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/csv/CROP1.csv

# %%
#Contamos cuantos recortes de cada categoría tenemos

# %%
import os

# Rutas principales para 'training' y 'test'
output_root = '/Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1'

# Subcarpetas a recorrer (benigno, maligno, sospechoso)
categorias = ['benigno', 'maligno', 'sospechoso']

# Función para contar cuántos archivos hay en una subcarpeta
def contar_archivos_en_categoria(ruta_base, categoria):
    categoria_path = os.path.join(ruta_base, categoria)
    try:
        # Listar archivos en la carpeta
        archivos = os.listdir(categoria_path)
        # Filtrar solo los archivos que sean imágenes (.png)
        archivos_imagenes = [archivo for archivo in archivos if archivo.endswith('.png')]
        return len(archivos_imagenes)
    except FileNotFoundError:
        print(f"No se encontró la carpeta: {categoria_path}")
        return 0

# Función para contar archivos en las carpetas de 'training' o 'test'
def contar_archivos_en_split(split_name):
    print(f"\nConteo de recortes en la carpeta '{split_name}':")
    
    # Rutas a las carpetas de masas y calcificaciones dentro de cada split ('training' o 'test')
    output_masas = os.path.join(output_root, split_name, 'masas')
    output_calcificaciones = os.path.join(output_root, split_name, 'calcificaciones')
    
    # Inicializar los contadores
    total_masas = 0
    total_calcificaciones = 0

    # Contar archivos en cada categoría de masas
    print("\nMasas:")
    for categoria in categorias:
        num_recortes = contar_archivos_en_categoria(output_masas, categoria)
        print(f"{categoria}: {num_recortes} recortes")
        total_masas += num_recortes

    # Contar archivos en cada categoría de calcificaciones
    print("\nCalcificaciones:")
    for categoria in categorias:
        num_recortes = contar_archivos_en_categoria(output_calcificaciones, categoria)
        print(f"{categoria}: {num_recortes} recortes")
        total_calcificaciones += num_recortes

    # Calcular el total de recortes
    total_recortes = total_masas + total_calcificaciones

    print(f"\nTotal de recortes en 'masas': {total_masas}")
    print(f"Total de recortes en 'calcificaciones': {total_calcificaciones}")
    print(f"Total general de recortes en '{split_name}': {total_recortes}")

# Contar archivos en las carpetas 'training' y 'test'
contar_archivos_en_split('training')
contar_archivos_en_split('test')
# Out:
# Conteo de recortes en la carpeta 'training':
#
# Masas:
# benigno: 443 recortes
# maligno: 90 recortes
# sospechoso: 372 recortes
#
# Calcificaciones:
# benigno: 54 recortes
# maligno: 33 recortes
# sospechoso: 224 recortes
#
# Total de recortes en 'masas': 905
# Total de recortes en 'calcificaciones': 311
# Total general de recortes en 'training': 1216
#
# Conteo de recortes en la carpeta 'test':
#
# Masas:
# benigno: 123 recortes
# maligno: 14 recortes
# sospechoso: 81 recortes
#
# Calcificaciones:
# benigno: 11 recortes
# maligno: 20 recortes
# sospechoso: 60 recortes
#
# Total de recortes en 'masas': 218
# Total de recortes en 'calcificaciones': 91
# Total general de recortes en 'test': 309

# %% [markdown]
# #### Visualizamos un recorte de cada categoría

# %%
import os
import matplotlib.pyplot as plt
import cv2

# Ruta principal donde están las carpetas de 'training' y 'test'
output_root = '/Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/ROICROP1'

# Función para contar imágenes en las subcarpetas y plotear una de cada una
def count_images_and_plot_example():
    for split in ['training', 'test']:
        split_path = os.path.join(output_root, split)
        if not os.path.exists(split_path):
            print(f"No se encontró la carpeta: {split_path}")
            continue
        
        for category in ['masas', 'calcificaciones']:
            category_path = os.path.join(split_path, category)
            
            for diagnosis in ['benigno', 'maligno', 'sospechoso']:
                diagnosis_path = os.path.join(category_path, diagnosis)
                
                if os.path.exists(diagnosis_path):
                    # Listar las imágenes en la carpeta
                    images = [f for f in os.listdir(diagnosis_path) if f.endswith('.png')]
                    num_images = len(images)
                    
                    # Imprimir el conteo de imágenes
                    print(f"Carpeta: {split}/{category}/{diagnosis} - {num_images} imágenes")
                    
                    if num_images > 0:
                        # Mostrar una imagen como ejemplo
                        image_path = os.path.join(diagnosis_path, images[0])
                        img = cv2.imread(image_path)
                        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convertir BGR a RGB para mostrar correctamente en matplotlib
                        
                        plt.figure(figsize=(5, 5))
                        plt.imshow(img)
                        plt.title(f"{split}/{category}/{diagnosis} - Ejemplo de imagen")
                        plt.axis('off')
                        plt.show()
                else:
                    print(f"No se encontró la carpeta: {diagnosis_path}")

# Ejecutar la función
count_images_and_plot_example()
# Out:
# Carpeta: training/masas/benigno - 443 imágenes
# Carpeta: training/masas/maligno - 90 imágenes
# Carpeta: training/masas/sospechoso - 372 imágenes
# Carpeta: training/calcificaciones/benigno - 54 imágenes
# Carpeta: training/calcificaciones/maligno - 33 imágenes
# Carpeta: training/calcificaciones/sospechoso - 224 imágenes
# Carpeta: test/masas/benigno - 123 imágenes
# Carpeta: test/masas/maligno - 14 imágenes
# Carpeta: test/masas/sospechoso - 81 imágenes
# Carpeta: test/calcificaciones/benigno - 11 imágenes
# Carpeta: test/calcificaciones/maligno - 20 imágenes
# Carpeta: test/calcificaciones/sospechoso - 60 imágenes
