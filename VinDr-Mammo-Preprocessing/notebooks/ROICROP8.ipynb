# %%
import os
import cv2
import pydicom
import numpy as np
import pandas as pd
from pydicom.pixel_data_handlers.util import apply_voi_lut

# Rutas al dataset y archivos
dicom_root = '/Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/subset_datos/images_with_other'
csv_path = '/Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/csv/others_with_image_names.csv'
output_root = '/Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8'  # Cambiado a ROICROP7

# Crear carpetas principales (training y test)
train_folder = os.path.join(output_root, 'training')
test_folder = os.path.join(output_root, 'test')

os.makedirs(train_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)

# Crear carpetas de masas, calcificaciones y otros, y sus subcarpetas (benigno, maligno, sospechoso)
for split_folder in [train_folder, test_folder]:
    for category in ['masas', 'calcificaciones', 'otros']:
        for birads_category in ['benigno', 'maligno', 'sospechoso']:
            os.makedirs(os.path.join(split_folder, category, birads_category), exist_ok=True)

# Tamaño objetivo al que queremos llegar para el recorte (299x299 píxeles)
TARGET_SIZE = (299, 299)

# Leer las anotaciones CSV que contienen las coordenadas de la ROI
ss1 = pd.read_csv(csv_path)

# Limpiar las categorías eliminando los caracteres adicionales
ss1['finding_categories'] = ss1['finding_categories'].apply(lambda x: x.strip("[]'"))

# Crear un DataFrame vacío para guardar las nuevas coordenadas
ss1_rescaled = pd.DataFrame(columns=ss1.columns)

# Lista de subcategorías para la categoría 'otros'
otros_categories = [
    'Focal Asymmetry',
    'Architectural Distortion',
    'Asymmetry',
    'Suspicious Lymph Node',
    'Skin Thickening',
    'Global Asymmetry',
    'Nipple Retraction',
    'Skin Retraction'
]

# Función para obtener la ruta del archivo DICOM usando image_id
def get_dicom_path(image_id):
    for study_id in os.listdir(dicom_root):
        study_path = os.path.join(dicom_root, study_id)
        if os.path.isdir(study_path):
            dicom_path = os.path.join(study_path, image_id + '.dicom')
            if os.path.exists(dicom_path):
                return dicom_path
    raise FileNotFoundError(f"No se encontró el archivo DICOM para image_id: {image_id}")

# Función para mapear BIRADS a categorías
def map_birads_to_category(birads):
    if birads in ['BI-RADS 0', 'BI-RADS 1', 'BI-RADS 2', 'BI-RADS 3']:
        return 'benigno'
    elif birads == 'BI-RADS 4':
        return 'sospechoso'
    elif birads in ['BI-RADS 5', 'BI-RADS 6']:
        return 'maligno'
    else:
        print(f"Advertencia: BIRADS desconocido '{birads}'. Asignando a 'benigno'.")
        return 'benigno'

# Función para aplicar el recorte basado en el centro de la ROI, con padding en el lado mayor
def extract_roi(image_name, split, birads, finding_categories, ss1_rescaled):
    # Obtener el image_id (parte antes del guión bajo "_")
    image_id = image_name.split('_')[0]
    dicom_path = get_dicom_path(image_id)

    # Leer la imagen DICOM
    dicom = pydicom.dcmread(dicom_path)
    original_image = dicom.pixel_array

    # Aplicar VOI LUT con prefer_lut=True (priorizando LUT si está presente)
    img_windowed = apply_voi_lut(original_image, dicom, prefer_lut=True)

    # Manejar Photometric Interpretation si es MONOCHROME1 (invertir la imagen)
    photometric_interpretation = dicom.get('PhotometricInterpretation', 'UNKNOWN')
    if photometric_interpretation == 'MONOCHROME1':
        img_windowed = img_windowed.max() - img_windowed
        print(f"Imagen {image_name} tiene Photometric Interpretation: {photometric_interpretation} (invertida)")
    else:
        print(f"Imagen {image_name} tiene Photometric Interpretation: {photometric_interpretation}")

    # Normalizar la imagen para que esté en el rango [0, 255]
    img_windowed = (img_windowed - img_windowed.min()) / (img_windowed.max() - img_windowed.min()) * 255
    img_windowed = img_windowed.astype(np.uint8)

    # Extraer las coordenadas de la ROI desde el CSV utilizando el image_name
    try:
        x1 = int(ss1.loc[ss1['image_name'] == image_name, 'xmin'].values[0])
        y1 = int(ss1.loc[ss1['image_name'] == image_name, 'ymin'].values[0])
        x2 = int(ss1.loc[ss1['image_name'] == image_name, 'xmax'].values[0])
        y2 = int(ss1.loc[ss1['image_name'] == image_name, 'ymax'].values[0])
    except IndexError:
        print(f"Error: No se encontraron coordenadas para la ROI de la imagen {image_name}.")
        return ss1_rescaled

    # Verificar que las coordenadas sean válidas
    x1 = max(0, x1)
    y1 = max(0, y1)
    x2 = min(img_windowed.shape[1], x2)
    y2 = min(img_windowed.shape[0], y2)

    # Calcular el tamaño original del recorte
    width = x2 - x1
    height = y2 - y1

    # Agregar padding del 10% al lado mayor y ajustar el lado menor para que sea cuadrado
    if width > height:
        # El ancho es mayor, agregar padding del 10% al ancho
        padding_x = int(width * 0.1)
        width += padding_x
        new_width = width
        new_height = new_width  # Ajustar el alto para hacer la imagen cuadrada
        padding_y = (new_height - height) // 2
    else:
        # El alto es mayor, agregar padding del 10% al alto
        padding_y = int(height * 0.1)
        height += padding_y
        new_height = height
        new_width = new_height  # Ajustar el ancho para hacer la imagen cuadrada
        padding_x = (new_width - width) // 2

    # Asegurarse de que los nuevos límites no excedan los límites de la imagen original
    x1_new = max(x1 - padding_x, 0)
    x2_new = min(x2 + padding_x, img_windowed.shape[1])
    y1_new = max(y1 - padding_y, 0)
    y2_new = min(y2 + padding_y, img_windowed.shape[0])

    # Recortar la imagen utilizando los nuevos límites ajustados
    crop = img_windowed[y1_new:y2_new, x1_new:x2_new]

    # Verificar si el recorte no está vacío
    if crop.size == 0:
        print(f"Error: El recorte para la imagen {image_name} está vacío.")
        return ss1_rescaled

    # Redimensionar la imagen al tamaño objetivo
    crop_resized = cv2.resize(crop, TARGET_SIZE)

    # Calcular las nuevas coordenadas reescaladas
    scale_x = TARGET_SIZE[0] / crop.shape[1]
    scale_y = TARGET_SIZE[1] / crop.shape[0]

    xmin_rescaled = int((x1 - x1_new) * scale_x)
    ymin_rescaled = int((y1 - y1_new) * scale_y)
    xmax_rescaled = int((x2 - x1_new) * scale_x)
    ymax_rescaled = int((y2 - y1_new) * scale_y)

    # Determinar el directorio base según el split
    if split.lower() in ['train', 'training']:
        base_dir = train_folder
    elif split.lower() == 'test':
        base_dir = test_folder
    else:
        print(f"Error: Split desconocido '{split}' para la imagen {image_name}.")
        return ss1_rescaled

    # Determinar la categoría de salida
    if finding_categories == 'Mass':
        output_dir = os.path.join(base_dir, 'masas')
    elif finding_categories == 'Suspicious Calcification':
        output_dir = os.path.join(base_dir, 'calcificaciones')
    elif finding_categories in otros_categories:
        output_dir = os.path.join(base_dir, 'otros')
    else:
        print(f"Error: Categoría desconocida '{finding_categories}' para la imagen {image_name}.")
        return ss1_rescaled

    # Mapear BIRADS a categoría
    birads_category = map_birads_to_category(birads)
    output_dir = os.path.join(output_dir, birads_category)

    # Guardar la imagen recortada
    roi_filename = f"{image_name}.png"
    output_path = os.path.join(output_dir, roi_filename)
    cv2.imwrite(output_path, crop_resized)
    print(f"Imagen ROI guardada en: {output_path}")

    # Guardar las coordenadas reescaladas
    new_row = ss1.loc[ss1['image_name'] == image_name].copy()
    new_row['xmin'] = xmin_rescaled
    new_row['ymin'] = ymin_rescaled
    new_row['xmax'] = xmax_rescaled
    new_row['ymax'] = ymax_rescaled
    ss1_rescaled = pd.concat([ss1_rescaled, new_row], ignore_index=True)

    return ss1_rescaled

# Función para procesar todas las imágenes
def process_all_images():
    global ss1_rescaled
    for _, row in ss1.iterrows():
        image_name = row['image_name']
        split = row['split']  # La columna 'split' tiene los valores 'train', 'training', o 'test'
        
        # Obtener 'birads' de 'finding_birads' o 'breast_birads'
        birads = row.get('finding_birads', '')
        if pd.isna(birads) or birads.strip() == '':
            birads = row.get('breast_birads', '')
            if pd.isna(birads) or birads.strip() == '':
                print(f"Advertencia: No se encontró 'finding_birads' ni 'breast_birads' para la imagen {image_name}. Asignando 'BI-RADS 0'.")
                birads = 'BI-RADS 0'
        
        finding_categories = row['finding_categories']

        # Procesar la imagen
        ss1_rescaled = extract_roi(image_name, split, birads, finding_categories, ss1_rescaled)

    # Guardar el nuevo CSV
    new_csv_path = '/Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/csv/CROP8.csv'  # Cambiado a CROP7.csv
    ss1_rescaled.to_csv(new_csv_path, index=False)
    print(f"Nuevo CSV guardado en: {new_csv_path}")

# Ejecutar el procesamiento
process_all_images()
# Out:
# Imagen 001ade2a3cb53fd808bd2856a0df5413_0 tiene Photometric Interpretation: MONOCHROME1 (invertida)
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/001ade2a3cb53fd808bd2856a0df5413_0.png
# Imagen 001ade2a3cb53fd808bd2856a0df5413_1 tiene Photometric Interpretation: MONOCHROME1 (invertida)
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/001ade2a3cb53fd808bd2856a0df5413_1.png
# Imagen 001ade2a3cb53fd808bd2856a0df5413_2 tiene Photometric Interpretation: MONOCHROME1 (invertida)
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/001ade2a3cb53fd808bd2856a0df5413_2.png
# Imagen 002074412a8fc178c271fb93b55c3e29_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/002074412a8fc178c271fb93b55c3e29_0.png
# Imagen 002460132586dc0c7b88a59dce6e77bd_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/002460132586dc0c7b88a59dce6e77bd_0.png
# Imagen 005869cc3078b5868e83197922b74c62_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/benigno/005869cc3078b5868e83197922b74c62_0.png
# Imagen 005918369ec07b1aed37d1dd78bc57fe_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/sospechoso/005918369ec07b1aed37d1dd78bc57fe_0.png
# Imagen 00857417d07096982013956033da1f75_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/calcificaciones/sospechoso/00857417d07096982013956033da1f75_0.png
# Imagen 008bc6050f6d31fc255e5d87bcc87ba2_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/sospechoso/008bc6050f6d31fc255e5d87bcc87ba2_0.png
# Imagen 008c66563c73b2f5b8e42915b2cd6af5_0 tiene Photometric Interpretation: MONOCHROME1 (invertida)
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/masas/benigno/008c66563c73b2f5b8e42915b2cd6af5_0.png
# Imagen 00be38a5c0566291168fe381ba0028e6_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/00be38a5c0566291168fe381ba0028e6_0.png
# Imagen 00ec2be128f964da6f0b0ba179c4d138_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/00ec2be128f964da6f0b0ba179c4d138_0.png
# Imagen 013e4b7bcdaf536c4e37b4125ab8148b_0 tiene Photometric Interpretation: MONOCHROME1 (invertida)
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/maligno/013e4b7bcdaf536c4e37b4125ab8148b_0.png
# /var/folders/ds/4z7lc9ld4mqb377_3t2v4lxm0000gn/T/ipykernel_1092/4008557562.py:195: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ss1_rescaled = pd.concat([ss1_rescaled, new_row], ignore_index=True)
# Imagen 01599597388f3185563decc34945f6b3_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/sospechoso/01599597388f3185563decc34945f6b3_0.png
# Imagen 0171ab32059f4c226164a13c311f6824_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/0171ab32059f4c226164a13c311f6824_0.png
# Imagen 01958718afdf303581e758cdf34eaf8a_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/masas/sospechoso/01958718afdf303581e758cdf34eaf8a_0.png
# Imagen 019b9f6365fa641db040b5b643fadc42_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/otros/sospechoso/019b9f6365fa641db040b5b643fadc42_0.png
# Imagen 01df962b078e38500bf9dd9969a50083_0 tiene Photometric Interpretation: MONOCHROME1 (invertida)
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/maligno/01df962b078e38500bf9dd9969a50083_0.png
# Imagen 01fb871dc222684a9950609b62b76772_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/01fb871dc222684a9950609b62b76772_0.png
# Imagen 020a5433c9b16a5c493b5d9902d08e90_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/benigno/020a5433c9b16a5c493b5d9902d08e90_0.png
# Imagen 02895cbbcb504f54c6882c4c5695f563_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/02895cbbcb504f54c6882c4c5695f563_0.png
# Imagen 02b3206d267eb7f354113b0c5365127b_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/calcificaciones/sospechoso/02b3206d267eb7f354113b0c5365127b_0.png
# Imagen 02d253f51556e2e0af63525de2e9ff74_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/02d253f51556e2e0af63525de2e9ff74_0.png
# Imagen 02d253f51556e2e0af63525de2e9ff74_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/02d253f51556e2e0af63525de2e9ff74_1.png
# Imagen 02d253f51556e2e0af63525de2e9ff74_2 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/02d253f51556e2e0af63525de2e9ff74_2.png
# Imagen 02db389409297f62ae588b4d03c46c6a_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/otros/benigno/02db389409297f62ae588b4d03c46c6a_0.png
# Imagen 031592807c30b54e2fb4bd2400e634e8_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/031592807c30b54e2fb4bd2400e634e8_0.png
# Imagen 03234e390d3f2c9c07889e1687eafbb8_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/sospechoso/03234e390d3f2c9c07889e1687eafbb8_0.png
# Imagen 032ab9e0ecd5fd673517ffa3eb805d15_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/032ab9e0ecd5fd673517ffa3eb805d15_0.png
# Imagen 03674edf018ba8eef3c2857d1aa3305b_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/masas/sospechoso/03674edf018ba8eef3c2857d1aa3305b_0.png
# Imagen 03b3656c726cbe0d79c86a25d4296559_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/maligno/03b3656c726cbe0d79c86a25d4296559_0.png
# Imagen 03b3656c726cbe0d79c86a25d4296559_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/03b3656c726cbe0d79c86a25d4296559_1.png
# Imagen 03e464754732750f5828aeb94af68b22_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/03e464754732750f5828aeb94af68b22_0.png
# Imagen 040cc172596bded4092c44094dc33fb7_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/maligno/040cc172596bded4092c44094dc33fb7_0.png
# Imagen 040cc172596bded4092c44094dc33fb7_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/040cc172596bded4092c44094dc33fb7_1.png
# Imagen 0426e31fea8079ce30b796c80321a17c_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/0426e31fea8079ce30b796c80321a17c_0.png
# Imagen 042733688eecb852ea06140448a8b1bf_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/042733688eecb852ea06140448a8b1bf_0.png
# Imagen 04c64dd7683662188094816c7c2ca88d_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/04c64dd7683662188094816c7c2ca88d_0.png
# Imagen 050c2f6caf47f439d62e1fc8942396f6_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/050c2f6caf47f439d62e1fc8942396f6_0.png
# Imagen 051525b959eefb14e973acc7ab8fcfe0_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/051525b959eefb14e973acc7ab8fcfe0_0.png
# Imagen 051c9cdca609082df5257bde8b1ec127_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/benigno/051c9cdca609082df5257bde8b1ec127_0.png
# Imagen 05b027272d8159658b5f9a51e22e734f_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/benigno/05b027272d8159658b5f9a51e22e734f_0.png
# Imagen 05dc96041c041ef9d6ec1cb2c86d86bf_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/benigno/05dc96041c041ef9d6ec1cb2c86d86bf_0.png
# Imagen 0602173c47d1b21fe548b2d852433a03_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/0602173c47d1b21fe548b2d852433a03_0.png
# Imagen 0602173c47d1b21fe548b2d852433a03_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/0602173c47d1b21fe548b2d852433a03_1.png
# Imagen 06073969e7453f71ac8108c6081dc9b8_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/06073969e7453f71ac8108c6081dc9b8_0.png
# Imagen 061bc49a16cad3bc2b479993f7e689f8_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/061bc49a16cad3bc2b479993f7e689f8_0.png
# Imagen 061bf98fabad5f9d99fb1919346a3a76_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/061bf98fabad5f9d99fb1919346a3a76_0.png
# Imagen 061bf98fabad5f9d99fb1919346a3a76_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/061bf98fabad5f9d99fb1919346a3a76_1.png
# Imagen 061c11537a514e894a296a7d72064a90_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/061c11537a514e894a296a7d72064a90_0.png
# Imagen 062a18f4573b5f00ad2a0ee1de37b99c_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/benigno/062a18f4573b5f00ad2a0ee1de37b99c_0.png
# Imagen 064f024583e9c1a7f0152f50aac1d16d_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/masas/benigno/064f024583e9c1a7f0152f50aac1d16d_0.png
# Imagen 06691f5dc2caa5f72c05d4b26af810cf_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/06691f5dc2caa5f72c05d4b26af810cf_0.png
# Imagen 06691f5dc2caa5f72c05d4b26af810cf_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/06691f5dc2caa5f72c05d4b26af810cf_1.png
# Imagen 06691f5dc2caa5f72c05d4b26af810cf_2 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/sospechoso/06691f5dc2caa5f72c05d4b26af810cf_2.png
# Imagen 06691f5dc2caa5f72c05d4b26af810cf_3 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/06691f5dc2caa5f72c05d4b26af810cf_3.png
# Imagen 06a407691cadae64cea5de8e8634a4ac_0 tiene Photometric Interpretation: MONOCHROME1 (invertida)
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/06a407691cadae64cea5de8e8634a4ac_0.png
# Imagen 070170f7ee43d9304852fafdde498b05_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/070170f7ee43d9304852fafdde498b05_0.png
# Imagen 0734a9dc7d6d89e8c91458545afeef9d_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/masas/sospechoso/0734a9dc7d6d89e8c91458545afeef9d_0.png
# Imagen 074775a9e94c93ed3ee32a82d2864c68_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/074775a9e94c93ed3ee32a82d2864c68_0.png
# Imagen 074775a9e94c93ed3ee32a82d2864c68_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/074775a9e94c93ed3ee32a82d2864c68_1.png
# Imagen 0784895356dd8e1e6ddcf536ff3d086f_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/benigno/0784895356dd8e1e6ddcf536ff3d086f_0.png
# Imagen 07aef1389177ff428c1f78ef882e704f_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/07aef1389177ff428c1f78ef882e704f_0.png
# Imagen 07b7e44dbce5dfef79947f2c8bb18a55_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/benigno/07b7e44dbce5dfef79947f2c8bb18a55_0.png
# Imagen 07e191bc54c3378f9fdf23ddecc47420_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/07e191bc54c3378f9fdf23ddecc47420_0.png
# Imagen 07e191bc54c3378f9fdf23ddecc47420_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/07e191bc54c3378f9fdf23ddecc47420_1.png
# Imagen 07f468d6fff5b3e3b512e4b95cf0cdda_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/07f468d6fff5b3e3b512e4b95cf0cdda_0.png
# Imagen 07f468d6fff5b3e3b512e4b95cf0cdda_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/sospechoso/07f468d6fff5b3e3b512e4b95cf0cdda_1.png
# Imagen 07f5863348560d0507bba86c8bba0586_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/07f5863348560d0507bba86c8bba0586_0.png
# Imagen 0806729f6ebeb658662051e8bdcfab3c_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/0806729f6ebeb658662051e8bdcfab3c_0.png
# Imagen 0806729f6ebeb658662051e8bdcfab3c_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/sospechoso/0806729f6ebeb658662051e8bdcfab3c_1.png
# Imagen 08490d6ee0e276c8a4daaf106d9a01e0_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/sospechoso/08490d6ee0e276c8a4daaf106d9a01e0_0.png
# Imagen 085915d953d1dcb1b70b6c3b8e68e1c5_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/085915d953d1dcb1b70b6c3b8e68e1c5_0.png
# Imagen 08a64894ac411114c25dd709e2bcc471_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/08a64894ac411114c25dd709e2bcc471_0.png
# Imagen 08a64894ac411114c25dd709e2bcc471_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/08a64894ac411114c25dd709e2bcc471_1.png
# Imagen 08a64894ac411114c25dd709e2bcc471_2 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/08a64894ac411114c25dd709e2bcc471_2.png
# Imagen 08a72a9160806b7b9334325d8870fa75_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/08a72a9160806b7b9334325d8870fa75_0.png
# Imagen 08fa2b8a39cb0bb6650a87dcad78b22f_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/08fa2b8a39cb0bb6650a87dcad78b22f_0.png
# Imagen 09025dbf5abd08828ecd4ebf03724341_0 tiene Photometric Interpretation: MONOCHROME1 (invertida)
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/maligno/09025dbf5abd08828ecd4ebf03724341_0.png
# Imagen 0939019fd916e0748e07d9546cd8bdf5_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/0939019fd916e0748e07d9546cd8bdf5_0.png
# Imagen 0953b01dfcb2ae000cae0a10b610fdcd_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/benigno/0953b01dfcb2ae000cae0a10b610fdcd_0.png
# Imagen 096cc0a03198a6ee828e92b6eaed4e78_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/096cc0a03198a6ee828e92b6eaed4e78_0.png
# Imagen 09c7c41323c29e418790f733ffb291c1_0 tiene Photometric Interpretation: MONOCHROME1 (invertida)
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/09c7c41323c29e418790f733ffb291c1_0.png
# Imagen 09c7c41323c29e418790f733ffb291c1_1 tiene Photometric Interpretation: MONOCHROME1 (invertida)
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/09c7c41323c29e418790f733ffb291c1_1.png
# Imagen 09e75ac07373f2e576fdcd909993b3bd_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/09e75ac07373f2e576fdcd909993b3bd_0.png
# Imagen 0a30a11ef223f40f82ec83fd72e2b5cc_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/benigno/0a30a11ef223f40f82ec83fd72e2b5cc_0.png
# Imagen 0a6f0eac805822cd00f3c25ba99569e8_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/maligno/0a6f0eac805822cd00f3c25ba99569e8_0.png
# Imagen 0a8fec5108d9cd3cd1f0d053db50f531_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/benigno/0a8fec5108d9cd3cd1f0d053db50f531_0.png
# Imagen 0aa8394efecbfb0f5c4a66ffbd215912_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/0aa8394efecbfb0f5c4a66ffbd215912_0.png
# Imagen 0abdf3f3255cb44a2a15908a811fe6e3_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/0abdf3f3255cb44a2a15908a811fe6e3_0.png
# Imagen 0ac950834b6f143b8fc1b3a1b2102faa_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/sospechoso/0ac950834b6f143b8fc1b3a1b2102faa_0.png
# Imagen 0adb22b2b24d61c511acbe028648532e_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/masas/sospechoso/0adb22b2b24d61c511acbe028648532e_0.png
# Imagen 0b0f0267ddfed609b645314fd6edecd7_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/benigno/0b0f0267ddfed609b645314fd6edecd7_0.png
# Imagen 0b39adfdce0aafaa1ff02e9633e9cac5_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/benigno/0b39adfdce0aafaa1ff02e9633e9cac5_0.png
# Imagen 0b597a53d015b5d2c2df81f4c19eeea0_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/0b597a53d015b5d2c2df81f4c19eeea0_0.png
# Imagen 0b597a53d015b5d2c2df81f4c19eeea0_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/maligno/0b597a53d015b5d2c2df81f4c19eeea0_1.png
# Imagen 0b873faadf6723e422e7ad7c1accc7c0_0 tiene Photometric Interpretation: MONOCHROME1 (invertida)
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/masas/benigno/0b873faadf6723e422e7ad7c1accc7c0_0.png
# Imagen 0b982200144c13b7302365e7f01c490d_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/sospechoso/0b982200144c13b7302365e7f01c490d_0.png
# Imagen 0b982200144c13b7302365e7f01c490d_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/0b982200144c13b7302365e7f01c490d_1.png
# Imagen 0bac94530476031873566b909b8f1161_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/0bac94530476031873566b909b8f1161_0.png
# Imagen 0bb148da1406b21011529bb886c17e79_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/0bb148da1406b21011529bb886c17e79_0.png
# Imagen 0bb148da1406b21011529bb886c17e79_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/maligno/0bb148da1406b21011529bb886c17e79_1.png
# Imagen 0bc4de293c8632352519d9aa87245e96_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/benigno/0bc4de293c8632352519d9aa87245e96_0.png
# Imagen 0bcbcbbe010d72178ba66ded4ad519c4_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/0bcbcbbe010d72178ba66ded4ad519c4_0.png
# Imagen 0c19be554e27e2fdc2fe05ad954e825c_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/0c19be554e27e2fdc2fe05ad954e825c_0.png
# Imagen 0c401b1b7faaa89afc4a68983f074b16_0 tiene Photometric Interpretation: MONOCHROME1 (invertida)
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/maligno/0c401b1b7faaa89afc4a68983f074b16_0.png
# Imagen 0c48ef2d25c7fe685e4a9d20b676c3a7_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/0c48ef2d25c7fe685e4a9d20b676c3a7_0.png
# Imagen 0c57e79ec6fc2ad0aa38ae8e2f54af07_0 tiene Photometric Interpretation: MONOCHROME1 (invertida)
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/0c57e79ec6fc2ad0aa38ae8e2f54af07_0.png
# Imagen 0cab307846e0ff5ff6f302421c539605_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/benigno/0cab307846e0ff5ff6f302421c539605_0.png
# Imagen 0cc9394905ef9d2527799723b4e87c72_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/sospechoso/0cc9394905ef9d2527799723b4e87c72_0.png
# Imagen 0cc9394905ef9d2527799723b4e87c72_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/sospechoso/0cc9394905ef9d2527799723b4e87c72_1.png
# Imagen 0cf9cd3d36a7bfb95e66c0ba482eb8c0_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/maligno/0cf9cd3d36a7bfb95e66c0ba482eb8c0_0.png
# Imagen 0cf9cd3d36a7bfb95e66c0ba482eb8c0_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/maligno/0cf9cd3d36a7bfb95e66c0ba482eb8c0_1.png
# Imagen 0cf9cd3d36a7bfb95e66c0ba482eb8c0_2 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/maligno/0cf9cd3d36a7bfb95e66c0ba482eb8c0_2.png
# Imagen 0d0826dc6e633a7729ea56fa7390c508_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/0d0826dc6e633a7729ea56fa7390c508_0.png
# Imagen 0d08356a2638c214fbc6cbeb24251c0c_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/0d08356a2638c214fbc6cbeb24251c0c_0.png
# Imagen 0d0c76cf04069b224806e8d8d3a9351b_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/0d0c76cf04069b224806e8d8d3a9351b_0.png
# Imagen 0d58856b402c571d3fa0fc19d26267ca_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/0d58856b402c571d3fa0fc19d26267ca_0.png
# Imagen 0d58856b402c571d3fa0fc19d26267ca_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/0d58856b402c571d3fa0fc19d26267ca_1.png
# Imagen 0d6987fc066d2fad238b5c15f4e9bf8e_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/calcificaciones/sospechoso/0d6987fc066d2fad238b5c15f4e9bf8e_0.png
# Imagen 0d6987fc066d2fad238b5c15f4e9bf8e_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/otros/sospechoso/0d6987fc066d2fad238b5c15f4e9bf8e_1.png
# Imagen 0d818b48634b775f4c15cc0dd8a56b69_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/0d818b48634b775f4c15cc0dd8a56b69_0.png
# Imagen 0d9de2c106f154c469b0d0b05980fb5e_0 tiene Photometric Interpretation: MONOCHROME1 (invertida)
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/0d9de2c106f154c469b0d0b05980fb5e_0.png
# Imagen 0d9de2c106f154c469b0d0b05980fb5e_1 tiene Photometric Interpretation: MONOCHROME1 (invertida)
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/0d9de2c106f154c469b0d0b05980fb5e_1.png
# Imagen 0dac8664468ff3ab7a3e24fda8053cf6_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/masas/benigno/0dac8664468ff3ab7a3e24fda8053cf6_0.png
# Imagen 0dbc1663eceef924f0f339604af18364_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/0dbc1663eceef924f0f339604af18364_0.png
# Imagen 0dbc1663eceef924f0f339604af18364_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/0dbc1663eceef924f0f339604af18364_1.png
# Imagen 0dbc1663eceef924f0f339604af18364_2 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/0dbc1663eceef924f0f339604af18364_2.png
# Imagen 0dbc1663eceef924f0f339604af18364_3 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/maligno/0dbc1663eceef924f0f339604af18364_3.png
# Imagen 0dc38f7b2936fff46ec10a0beb5aaeb2_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/maligno/0dc38f7b2936fff46ec10a0beb5aaeb2_0.png
# Imagen 0de15bbc9f84e965d634e2bc686d11f1_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/0de15bbc9f84e965d634e2bc686d11f1_0.png
# Imagen 0e188b766ff729c0332e3f49599d2796_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/0e188b766ff729c0332e3f49599d2796_0.png
# Imagen 0e31855d02eadf8670ffaeeaeddbf229_0 tiene Photometric Interpretation: MONOCHROME1 (invertida)
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/masas/benigno/0e31855d02eadf8670ffaeeaeddbf229_0.png
# Imagen 0e3db7bbea14c6dd5dbab7b95bfe82e4_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/masas/benigno/0e3db7bbea14c6dd5dbab7b95bfe82e4_0.png
# Imagen 0e9481c18a33d55b1fa0a353f53e0d6a_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/0e9481c18a33d55b1fa0a353f53e0d6a_0.png
# Imagen 0f0009a94c664c2b67ae78fd675f323c_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/0f0009a94c664c2b67ae78fd675f323c_0.png
# Imagen 0f0009a94c664c2b67ae78fd675f323c_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/0f0009a94c664c2b67ae78fd675f323c_1.png
# Imagen 0f22280d1836afa323f2023d12be9573_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/0f22280d1836afa323f2023d12be9573_0.png
# Imagen 0f3a1f45d84cbe6b77b3e9354bb9ea1a_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/0f3a1f45d84cbe6b77b3e9354bb9ea1a_0.png
# Imagen 0f5457dbb9449aa73bb9cf62e1c10847_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/sospechoso/0f5457dbb9449aa73bb9cf62e1c10847_0.png
# Imagen 0f5457dbb9449aa73bb9cf62e1c10847_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/0f5457dbb9449aa73bb9cf62e1c10847_1.png
# Imagen 0f714f0b91dcd0ff05a60290440d1004_0 tiene Photometric Interpretation: MONOCHROME1 (invertida)
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/masas/benigno/0f714f0b91dcd0ff05a60290440d1004_0.png
# Imagen 0fb063fe3b46db2bbe83d124a3793101_0 tiene Photometric Interpretation: MONOCHROME1 (invertida)
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/0fb063fe3b46db2bbe83d124a3793101_0.png
# Imagen 0fdce081d72ba8455337d41ca7ab3073_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/benigno/0fdce081d72ba8455337d41ca7ab3073_0.png
# Imagen 0fe4b46af3e804d83f490f1b1dafba3b_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/benigno/0fe4b46af3e804d83f490f1b1dafba3b_0.png
# Imagen 100f9f1f5392774416f1a1e66a5a4c71_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/masas/sospechoso/100f9f1f5392774416f1a1e66a5a4c71_0.png
# Imagen 101906844b5a3d7fab9df630876d24fd_0 tiene Photometric Interpretation: MONOCHROME1 (invertida)
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/maligno/101906844b5a3d7fab9df630876d24fd_0.png
# Imagen 104bd2676dc8eec4debd4312b47a44d8_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/sospechoso/104bd2676dc8eec4debd4312b47a44d8_0.png
# Imagen 10e0f362333df810ac84a9db8fb3fd42_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/maligno/10e0f362333df810ac84a9db8fb3fd42_0.png
# Imagen 10e3136f3e11277d87ce71d123f7ba68_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/10e3136f3e11277d87ce71d123f7ba68_0.png
# Imagen 114d538a35b1b8e8ab15ba05d790dc8d_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/benigno/114d538a35b1b8e8ab15ba05d790dc8d_0.png
# Imagen 114d913843a055357575b57d86f8305b_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/benigno/114d913843a055357575b57d86f8305b_0.png
# Imagen 115600671e989b2ffeaac92d19d1f505_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/115600671e989b2ffeaac92d19d1f505_0.png
# Imagen 11b8d57615519367276e766b61684f04_0 tiene Photometric Interpretation: MONOCHROME1 (invertida)
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/calcificaciones/sospechoso/11b8d57615519367276e766b61684f04_0.png
# Imagen 11b8d57615519367276e766b61684f04_1 tiene Photometric Interpretation: MONOCHROME1 (invertida)
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/masas/sospechoso/11b8d57615519367276e766b61684f04_1.png
# Imagen 11b953e33bdaee7933f8d1db574942af_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/11b953e33bdaee7933f8d1db574942af_0.png
# Imagen 11c55b82a0c6ceebf5984208ec343b4d_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/benigno/11c55b82a0c6ceebf5984208ec343b4d_0.png
# Imagen 11d1c20d269f487d47fa5fc80c6f7722_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/calcificaciones/sospechoso/11d1c20d269f487d47fa5fc80c6f7722_0.png
# Imagen 11d7d3658b66d8515393a4c8189104c6_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/benigno/11d7d3658b66d8515393a4c8189104c6_0.png
# Imagen 11dbf2405e94335db8d8011db532a5ac_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/calcificaciones/sospechoso/11dbf2405e94335db8d8011db532a5ac_0.png
# Imagen 11dbf2405e94335db8d8011db532a5ac_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/otros/maligno/11dbf2405e94335db8d8011db532a5ac_1.png
# Imagen 11ef96e59a58cdae12a4ea27b1b3ca6c_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/benigno/11ef96e59a58cdae12a4ea27b1b3ca6c_0.png
# Imagen 12284c56ca4887b1747c1f45bce853f1_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/12284c56ca4887b1747c1f45bce853f1_0.png
# Imagen 12284c56ca4887b1747c1f45bce853f1_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/12284c56ca4887b1747c1f45bce853f1_1.png
# Imagen 12284c56ca4887b1747c1f45bce853f1_2 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/12284c56ca4887b1747c1f45bce853f1_2.png
# Imagen 123b1009ba5b19b0f96f6d5d6804d98a_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/benigno/123b1009ba5b19b0f96f6d5d6804d98a_0.png
# Imagen 1246963cc624ac0b8a2fd974f463a825_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/otros/benigno/1246963cc624ac0b8a2fd974f463a825_0.png
# Imagen 1297fb4b53170324f0f6eeaf74c4449c_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/1297fb4b53170324f0f6eeaf74c4449c_0.png
# Imagen 1297fb4b53170324f0f6eeaf74c4449c_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/1297fb4b53170324f0f6eeaf74c4449c_1.png
# Imagen 129b633979a43461369df710e69e111d_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/129b633979a43461369df710e69e111d_0.png
# Imagen 12fcf7d55f2b52086c8ecb5fc8006db3_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/sospechoso/12fcf7d55f2b52086c8ecb5fc8006db3_0.png
# Imagen 132095e759b34fba0adcba4205e1b513_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/132095e759b34fba0adcba4205e1b513_0.png
# Imagen 1369c052ee3d713c0b5258920d0bccd0_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/benigno/1369c052ee3d713c0b5258920d0bccd0_0.png
# Imagen 1371cabdfe2afcbe30cf48047395c641_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/otros/sospechoso/1371cabdfe2afcbe30cf48047395c641_0.png
# Imagen 13be6c55646212a038555d19e9f9c086_0 tiene Photometric Interpretation: MONOCHROME1 (invertida)
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/13be6c55646212a038555d19e9f9c086_0.png
# Imagen 13dcce4e628d544820e41c43275b7806_0 tiene Photometric Interpretation: MONOCHROME1 (invertida)
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/sospechoso/13dcce4e628d544820e41c43275b7806_0.png
# Imagen 13dcce4e628d544820e41c43275b7806_1 tiene Photometric Interpretation: MONOCHROME1 (invertida)
# ...
# Imagen f8bbdcf948609aea0b384583364379e5_2 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/f8bbdcf948609aea0b384583364379e5_2.png
# Imagen f8bfea7bae6392d0db67fddb39dcee32_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/maligno/f8bfea7bae6392d0db67fddb39dcee32_0.png
# Imagen f909934b0d96d977fffee6ee0777a1a7_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/f909934b0d96d977fffee6ee0777a1a7_0.png
# Imagen f90d9c5b3c032980a35d7bface8e8fd4_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/f90d9c5b3c032980a35d7bface8e8fd4_0.png
# Imagen f90ec8e52522a65d1c0c9f999837cc6c_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/masas/benigno/f90ec8e52522a65d1c0c9f999837cc6c_0.png
# Imagen f910a580645aee0ea0147a66c27c6fbf_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/f910a580645aee0ea0147a66c27c6fbf_0.png
# Imagen f9326c0d08afc3d402d21dd075feed3b_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/sospechoso/f9326c0d08afc3d402d21dd075feed3b_0.png
# Imagen f978cb9d32a74171873fb280779aa37f_0 tiene Photometric Interpretation: MONOCHROME1 (invertida)
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/otros/sospechoso/f978cb9d32a74171873fb280779aa37f_0.png
# Imagen f978cb9d32a74171873fb280779aa37f_1 tiene Photometric Interpretation: MONOCHROME1 (invertida)
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/masas/sospechoso/f978cb9d32a74171873fb280779aa37f_1.png
# Imagen f97cd5b8d0049cbceda56350c01a66d5_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/f97cd5b8d0049cbceda56350c01a66d5_0.png
# Imagen f97cd5b8d0049cbceda56350c01a66d5_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/f97cd5b8d0049cbceda56350c01a66d5_1.png
# Imagen f97cd5b8d0049cbceda56350c01a66d5_2 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/sospechoso/f97cd5b8d0049cbceda56350c01a66d5_2.png
# Imagen f9918b3feb92e1f38a0c86a6a28c14a0_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/masas/benigno/f9918b3feb92e1f38a0c86a6a28c14a0_0.png
# Imagen f99e08afa8e94624cc4e4d71b272c44d_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/f99e08afa8e94624cc4e4d71b272c44d_0.png
# Imagen f9a54449757586583a8f36ccc821f7ac_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/f9a54449757586583a8f36ccc821f7ac_0.png
# Imagen fa0104443e2e60effcb1e0222a9b015d_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/maligno/fa0104443e2e60effcb1e0222a9b015d_0.png
# Imagen fa0104443e2e60effcb1e0222a9b015d_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/fa0104443e2e60effcb1e0222a9b015d_1.png
# Imagen fa0d61ab7e2e1115fa871ff94d457d9b_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/fa0d61ab7e2e1115fa871ff94d457d9b_0.png
# Imagen fa145776ca39abb6df42fc67e519bcf3_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/sospechoso/fa145776ca39abb6df42fc67e519bcf3_0.png
# Imagen fa145776ca39abb6df42fc67e519bcf3_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/sospechoso/fa145776ca39abb6df42fc67e519bcf3_1.png
# Imagen fa2f7816bf1b07f2104aa4edeff9b107_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/fa2f7816bf1b07f2104aa4edeff9b107_0.png
# Imagen fa4f9cc52819bd2aa35c57ad8a83113a_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/fa4f9cc52819bd2aa35c57ad8a83113a_0.png
# Imagen fa62bfb18ecd5fe37a4cc21b957a4eed_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/fa62bfb18ecd5fe37a4cc21b957a4eed_0.png
# Imagen fa81d6994805601937dd950bca2e61a0_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/fa81d6994805601937dd950bca2e61a0_0.png
# Imagen fa8e8eee66d4b88a869e9ced96a2238f_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/fa8e8eee66d4b88a869e9ced96a2238f_0.png
# Imagen fabc21b31c91a6f8b0900a6767d46515_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/benigno/fabc21b31c91a6f8b0900a6767d46515_0.png
# Imagen fabc21b31c91a6f8b0900a6767d46515_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/fabc21b31c91a6f8b0900a6767d46515_1.png
# Imagen fad1035fa251f5f7fc318dea403aa7dc_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/fad1035fa251f5f7fc318dea403aa7dc_0.png
# Imagen fae5f8cf37f37b672454a67ff7b16ef0_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/fae5f8cf37f37b672454a67ff7b16ef0_0.png
# Imagen fb16653152c4808c9e759888d15e42c4_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/maligno/fb16653152c4808c9e759888d15e42c4_0.png
# Imagen fb37f7f1423480f1173ff376ca8e6ada_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/fb37f7f1423480f1173ff376ca8e6ada_0.png
# Imagen fb3eca52ff53f6b49df9ea75bf2b9dd7_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/fb3eca52ff53f6b49df9ea75bf2b9dd7_0.png
# Imagen fb413cf6ef972090326d9886fa500aa2_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/fb413cf6ef972090326d9886fa500aa2_0.png
# Imagen fb70bcb1b4be4e6942a47e775b497aec_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/fb70bcb1b4be4e6942a47e775b497aec_0.png
# Imagen fbe89362c0679ef85b12823a1a3fd3de_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/benigno/fbe89362c0679ef85b12823a1a3fd3de_0.png
# Imagen fc35547785ce94420408f99bbfad57fb_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/fc35547785ce94420408f99bbfad57fb_0.png
# Imagen fc6a348a61d4282a66ac2dc6dbec5981_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/maligno/fc6a348a61d4282a66ac2dc6dbec5981_0.png
# Imagen fc6a348a61d4282a66ac2dc6dbec5981_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/maligno/fc6a348a61d4282a66ac2dc6dbec5981_1.png
# Imagen fc869569babcc087c18d01ff23b27a18_0 tiene Photometric Interpretation: MONOCHROME1 (invertida)
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/maligno/fc869569babcc087c18d01ff23b27a18_0.png
# Imagen fca53ee93a666b922a4d11c07501143f_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/benigno/fca53ee93a666b922a4d11c07501143f_0.png
# Imagen fcfc75c0adef3f1491137de3f855d39c_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/calcificaciones/sospechoso/fcfc75c0adef3f1491137de3f855d39c_0.png
# Imagen fd0c0b70adb9608b5b2dcf57f05668f3_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/fd0c0b70adb9608b5b2dcf57f05668f3_0.png
# Imagen fd3a1956f031a897741ae12ba7356b40_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/fd3a1956f031a897741ae12ba7356b40_0.png
# Imagen fd5b39474bd0c0e81bf3af47bbc0c487_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/sospechoso/fd5b39474bd0c0e81bf3af47bbc0c487_0.png
# Imagen fdc97a4e0c7da3511cad7b0f8f3f71f3_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/sospechoso/fdc97a4e0c7da3511cad7b0f8f3f71f3_0.png
# Imagen fde1086cce41c66b9efc68270f537837_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/fde1086cce41c66b9efc68270f537837_0.png
# Imagen fde1086cce41c66b9efc68270f537837_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/fde1086cce41c66b9efc68270f537837_1.png
# Imagen fde1086cce41c66b9efc68270f537837_2 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/fde1086cce41c66b9efc68270f537837_2.png
# Imagen fdef102a89845c81d40fa6c8869fb99a_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/fdef102a89845c81d40fa6c8869fb99a_0.png
# Imagen fe4273ea38a3028f91f80e5e12a84301_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/masas/benigno/fe4273ea38a3028f91f80e5e12a84301_0.png
# Imagen ff1006f34fb13f42dff90aff81dc33ce_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/calcificaciones/sospechoso/ff1006f34fb13f42dff90aff81dc33ce_0.png
# Imagen ff1ac3371deae6d83a882e5ac36378e6_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/sospechoso/ff1ac3371deae6d83a882e5ac36378e6_0.png
# Imagen ff476c753265aa0baa6685c58d5ef05a_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/masas/benigno/ff476c753265aa0baa6685c58d5ef05a_0.png
# Imagen ff6716b4004598670fa72d8cefea454c_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/test/masas/sospechoso/ff6716b4004598670fa72d8cefea454c_0.png
# Imagen ffac8bc2803630da2fb467c566d1f136_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/calcificaciones/sospechoso/ffac8bc2803630da2fb467c566d1f136_0.png
# Imagen ffb94da823c87898c7ce19b197dc24c9_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/ffb94da823c87898c7ce19b197dc24c9_0.png
# Imagen ffd951bc4cd3d91f8994d2d1d36f038d_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/sospechoso/ffd951bc4cd3d91f8994d2d1d36f038d_0.png
# Imagen ffe25766ac37ab145ae7f0bd78665f81_0 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/masas/benigno/ffe25766ac37ab145ae7f0bd78665f81_0.png
# Imagen ffe25766ac37ab145ae7f0bd78665f81_1 tiene Photometric Interpretation: MONOCHROME2
# Imagen ROI guardada en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/roi_images/ROICROP8/training/otros/sospechoso/ffe25766ac37ab145ae7f0bd78665f81_1.png
# Nuevo CSV guardado en: /Volumes/m2/Memoria/Code/PMM/VinDr-Mammo-Preprocessing/data/processed/csv/CROP8.csv

# %% [markdown]
# El script está diseñado para procesar imágenes DICOM de mamografías, extrayendo regiones de interés (ROIs) basadas en coordenadas proporcionadas en un archivo CSV.
#
# Primero, organiza las imágenes en categorías como masas, calcificaciones y otros, y subcategorías según los valores de BIRADS (benigno, maligno, sospechoso) dentro de carpetas de entrenamiento y prueba.
#
# Para cada imagen, el script localiza el archivo DICOM correspondiente, aplica ajustes como la inversión de la imagen si tiene una interpretación fotométrica MONOCHROME1, normaliza los valores de píxel, y realiza un recorte centrado con un padding del 10% en el lado mayor para mantener la proporción cuadrada.
#
# Posteriormente, redimensiona la ROI a un tamaño estándar de 299x299 píxeles y guarda tanto la imagen recortada como las nuevas coordenadas reescaladas en un archivo CSV (CROP8.csv).
#
# Este proceso asegura una organización estructurada y consistente de las ROIs, facilitando su uso para análisis posteriores o para el entrenamiento de modelos de aprendizaje automático.

# %% [markdown]
# Después de ejecutar el script de recorte, se realizó un conteo de las imágenes .png almacenadas en la carpeta ROICROP8 y sus subdirectorios.
#
# Los resultados obtenidos muestran una distribución detallada por categorías y subcategorías dentro de los splits de Training y Test.
#
# En el split de Training, se contabilizaron 443 imágenes benignas, 90 malignas y 372 sospechosas en masas; 54 benignas, 33 malignas y 224 sospechosas en calcificaciones; y 215 benignas, 43 malignas y 187 sospechosas en otros.
#
# En el split de Test, las cifras fueron 123 benignas, 14 malignas y 81 sospechosas en masas; 11 benignas, 20 malignas y 60 sospechosas en calcificaciones; y 49 benignas, 14 malignas y 47 sospechosas en otros.
#
# En total, se contabilizaron 2080 imágenes .png
